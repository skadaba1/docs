# %% [markdown]
# # BindCraft: Protein binder design
#
# <img src="https://github.com/martinpacesa/BindCraft/blob/main/pipeline.png?raw=true">
#
# Simple binder design pipeline using AlphaFold2 backpropagation, MPNN, and PyRosetta. Select your target and let the script do the rest of the work and finish once you have enough designs to order!
#
# The designs will be saved on your Google Drive under BindCraft/[design_name]/ and you can continue running the design pipeline if the session times out and it will continue adding new designs.

# %%
#@title Installation
# %%time
import os, time, gc, io
import contextlib
import json
from datetime import datetime
from ipywidgets import HTML, VBox
from IPython.display import display

if not os.path.isfile("bindcraft/params/done.txt"):
  print("Installing required BindCraft components")

  print("Pulling BindCraft code from Github")
  os.makedirs('/content/bindcraft/', exist_ok=True)
  # !git clone https://github.com/martinpacesa/BindCraft /content/bindcraft/
  os.system("chmod +x /content/bindcraft/functions/dssp")
  os.system("chmod +x /content/bindcraft/functions/DAlphaBall.gcc")

  print("Installing ColabDesign")
  os.system("(mkdir bindcraft/params; apt-get install aria2 -qq; \
  aria2c -q -x 16 https://storage.googleapis.com/alphafold/alphafold_params_2022-12-06.tar; \
  tar -xf alphafold_params_2022-12-06.tar -C bindcraft/params; touch bindcraft/params/done.txt )&")
  os.system("pip install git+https://github.com/sokrypton/ColabDesign.git")
  # for debugging purposes
  os.system("ln -s /usr/local/lib/python3.*/dist-packages/colabdesign colabdesign")

  print("Installing PyRosetta")
  os.system("pip install pyrosettacolabsetup")
  with contextlib.redirect_stdout(io.StringIO()):
    import pyrosettacolabsetup
    pyrosettacolabsetup.install_pyrosetta(serialization=True, cache_wheel_on_google_drive=False)

  # download params
  if not os.path.isfile("bindcraft/params/done.txt"):
    print("downloading AlphaFold params")
    while not os.path.isfile("bindcraft/params/done.txt"):
      time.sleep(5)

  print("BindCraft installation is finished, ready to run!")
else:
  print("BindCraft components already installed, ready to run!")
# Out:
# Installing required BindCraft components
# Pulling BindCraft code from Github
# Cloning into '/content/bindcraft'...
# remote: Enumerating objects: 226, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 226 (delta 74), reused 45 (delta 45), pack-reused 129 (from 1)
# Receiving objects: 100% (226/226), 3.45 MiB | 7.93 MiB/s, done.
# Resolving deltas: 100% (125/125), done.
# Installing ColabDesign
# Installing PyRosetta
# BindCraft installation is finished, ready to run!
# CPU times: user 1.87 s, sys: 199 ms, total: 2.07 s
# Wall time: 1min 55s

# %%
#@title Mount your Google Drive to save design results
from google.colab import drive
drive.mount('/content/drive')
currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Google drive mounted at: {currenttime}")

bindcraft_google_drive = '/content/drive/My Drive/BindCraft/'
os.makedirs(bindcraft_google_drive, exist_ok=True)
print("BindCraft folder successfully created in your drive!")
# Out:
# Mounted at /content/drive
# Google drive mounted at: 2024-12-03 22:29:31
# BindCraft folder successfully created in your drive!

# %%
import os, time, gc, io
import contextlib
import json
from datetime import datetime
from ipywidgets import HTML, VBox
from IPython.display import display

#@title Binder design settings
# @markdown ---
# @markdown Enter path where to save your designs. We recommend to save on Google drive so that you can continue generating at any time.
design_path = "/content/drive/MyDrive/BindCraft/PDL1/" # @param {"type":"string","placeholder":"/content/drive/MyDrive/BindCraft/PDL1/"}

# @markdown Enter the name that should be prefixed to your binders (generally target name).
binder_name = "PDL1" # @param {"type":"string","placeholder":"PDL1"}

# @markdown The path to the .pdb structure of your target. Can be an experimental or AlphaFold2 structure. We recommend trimming the structure to as small as needed, as the whole selected chains will be backpropagated through the network and can significantly increase running times.
starting_pdb = "/content/bindcraft/example/PDL1.pdb" # @param {"type":"string","placeholder":"/content/bindcraft/example/PDL1.pdb"}

# @markdown Which chains of your PDB to target? Can be one or multiple, in a comma-separated format. Other chains will be ignored during design.
chains = "A" # @param {"type":"string","placeholder":"A,C"}

# @markdown What positions to target in your protein of interest? For example `1,2-10` or chain specific `A1-10,B1-20` or entire chains `A`. If left blank, an appropriate site will be selected by the pipeline.
target_hotspot_residues = "" # @param {"type":"string","placeholder":""}

# @markdown What is the minimum and maximum size of binders you want to design? Pipeline will randomly sample different sizes between these values.
lengths = "25,25" # @param {"type":"string","placeholder":"70,150"}

# @markdown How many binder designs passing filters do you require?
number_of_final_designs = 10 # @param {"type":"integer","placeholder":"100"}
# @markdown ---
# @markdown Enter path on your Google drive (/content/drive/MyDrive/BindCraft/[binder_name].json) to previous target settings to continue design campaign. If left empty, it will use the settings above and generate a new settings json in your design output folder.
load_previous_target_settings = "" # @param {"type":"string","placeholder":""}
# @markdown ---

if load_previous_target_settings:
    target_settings_path = load_previous_target_settings
else:
    lengths = [int(x.strip()) for x in lengths.split(',') if len(lengths.split(',')) == 2]

    if len(lengths) != 2:
        raise ValueError("Incorrect specification of binder lengths.")

    settings = {
        "design_path": design_path,
        "binder_name": binder_name,
        "starting_pdb": starting_pdb,
        "chains": chains,
        "target_hotspot_residues": target_hotspot_residues,
        "lengths": lengths,
        "number_of_final_designs": number_of_final_designs
    }

    target_settings_path = os.path.join(design_path, binder_name+".json")
    os.makedirs(design_path, exist_ok=True)

    with open(target_settings_path, 'w') as f:
        json.dump(settings, f, indent=4)

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Binder design settings updated at: {currenttime}")
print(f"New .json file with target settings has been generated in: {target_settings_path}")
# Out:
# Binder design settings updated at: 2024-12-03 23:42:08
# New .json file with target settings has been generated in: /content/drive/MyDrive/BindCraft/PDL1/PDL1.json

# %%
#@title Advanced settings
# @markdown ---
# @markdown Which binder design protocol to run? Default is recommended. "Beta-sheet" promotes the design of more beta sheeted proteins, but requires more sampling. "Peptide" is optimised for helical peptide binders.
design_protocol = "Default" # @param ["Default","Beta-sheet","Peptide"]
# @markdown What interface design method to use?. "AlphaFold2" is the default, interface is generated by AlphaFold2. "MPNN" uses soluble MPNN to optimise the interface, but majority of residues still originate from AlphaFold2.
interface_protocol = "AlphaFold2" # @param ["AlphaFold2","MPNN"]
# @markdown What target template protocol to use? "Default" allows for limited amount flexibility. "Masked" allows for greater target flexibility on both sidechain and backbone level, but might result in reduced experimental success rates.
template_protocol = "Default" # @param ["Default","Masked"]
# @markdown ---

if design_protocol == "Default":
    design_protocol_tag = "default_4stage_multimer"
elif design_protocol == "Beta-sheet":
    design_protocol_tag = "betasheet_4stage_multimer"
elif design_protocol == "Peptide":
    design_protocol_tag = "peptide_3stage_multimer"
else:
    raise ValueError(f"Unsupported design protocol")

if interface_protocol == "AlphaFold2":
    interface_protocol_tag = ""
elif interface_protocol == "MPNN":
    interface_protocol_tag = "_mpnn"
else:
    raise ValueError(f"Unsupported interface protocol")

if template_protocol == "Default":
    template_protocol_tag = ""
elif template_protocol == "Masked":
    template_protocol_tag = "_flexible"
else:
    raise ValueError(f"Unsupported template protocol")

advanced_settings_path = "/content/bindcraft/settings_advanced/" + design_protocol_tag + interface_protocol_tag + template_protocol_tag + ".json"

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Advanced design settings updated at: {currenttime}")
# Out:
# Advanced design settings updated at: 2024-12-03 23:42:10

# %%
#@title Filters
# @markdown ---
# @markdown Which filters for designs to use? "Default" are recommended, "Peptide" are for the design of peptide binders, "Relaxed" are more permissive but may result in fewer experimental successes, "Peptide_Relaxed" are more permissive filters for non-helical peptides, "None" is for benchmarking.
filter_option = "Default" # @param ["Default", "Peptide", "Relaxed", "Peptide_Relaxed", "None"]
# @markdown ---

if filter_option == "Default":
    filter_settings_path = "/content/bindcraft/settings_filters/default_filters.json"
elif filter_option == "Peptide":
    filter_settings_path = "/content/bindcraft/settings_filters/peptide_filters.json"
elif filter_option == "Relaxed":
    filter_settings_path = "/content/bindcraft/settings_filters/relaxed_filters.json"
elif filter_option == "Peptide_Relaxed":
    filter_settings_path = "/content/bindcraft/settings_filters/peptide_relaxed_filters.json"
elif filter_option == "None":
    filter_settings_path = "/content/bindcraft/settings_filters/no_filters.json"
else:
    raise ValueError(f"Unsupported filter type")

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Filter settings updated at: {currenttime}")
# Out:
# Filter settings updated at: 2024-12-03 23:42:12

# %% [markdown]
# # Everything is set, BindCraft is ready to run!

# %%
# @title Import functions and settings
from bindcraft.functions import *

args = {"settings":target_settings_path,
        "filters":filter_settings_path,
        "advanced":advanced_settings_path}

# Check if JAX-capable GPU is available, otherwise exit
check_jax_gpu()

# perform checks of input setting files
settings_path, filters_path, advanced_path = (args["settings"], args["filters"], args["advanced"])

### load settings from JSON
target_settings, advanced_settings, filters = load_json_settings(settings_path, filters_path, advanced_path)

settings_file = os.path.basename(settings_path).split('.')[0]
filters_file = os.path.basename(filters_path).split('.')[0]
advanced_file = os.path.basename(advanced_path).split('.')[0]

### load AF2 model settings
design_models, prediction_models, multimer_validation = load_af2_models(advanced_settings["use_multimer_design"])

### perform checks on advanced_settings
bindcraft_folder = "colab"
advanced_settings = perform_advanced_settings_check(advanced_settings, bindcraft_folder)

### generate directories, design path names can be found within the function
design_paths = generate_directories(target_settings["design_path"])

### generate dataframes
trajectory_labels, design_labels, final_labels = generate_dataframe_labels()

trajectory_csv = os.path.join(target_settings["design_path"], 'trajectory_stats.csv')
mpnn_csv = os.path.join(target_settings["design_path"], 'mpnn_design_stats.csv')
final_csv = os.path.join(target_settings["design_path"], 'final_design_stats.csv')
failure_csv = os.path.join(target_settings["design_path"], 'failure_csv.csv')

create_dataframe(trajectory_csv, trajectory_labels)
create_dataframe(mpnn_csv, design_labels)
create_dataframe(final_csv, final_labels)
generate_filter_pass_csv(failure_csv, args["filters"])

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Loaded design functions and settings at: {currenttime}")
# Out:
# Available GPUs:
# NVIDIA A100-SXM4-40GB1: gpu
# Loaded design functions and settings at: 2024-12-03 23:42:17

# %%
#@title Initialise PyRosetta

####################################
####################################
####################################
### initialise PyRosetta
pr.init(f'-ignore_unrecognized_res -ignore_zero_occupancy -mute all -holes:dalphaball {advanced_settings["dalphaball_path"]} -corrections::beta_nov16 true -relax:default_repeats 1')
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2024 [Rosetta PyRosetta4.Release.python310.ubuntu.cxx11thread.serialization 2024.42+release.3366cf78a3df04339d1982e94531b77b098ddb99 2024-10-11T08:24:04] retrieved from: http://www.pyrosetta.org

# %%
#@title Run BindCraft!
####################################
###################### BindCraft Run
####################################
# Colab-specific: live displays
num_sampled_trajectories = len(pd.read_csv(trajectory_csv))
num_accepted_designs = len(pd.read_csv(final_csv))
sampled_trajectories_label = HTML(value=f"<h3 style='color: #1f77b4;'>Sampled Trajectories: <span style='color: #1f77b4;'>{num_sampled_trajectories}</span></h3>")
accepted_designs_label = HTML(value=f"<h3 style='color: #2ca02c;'>Accepted Designs: <span style='color: #2ca02c;'>{num_accepted_designs}</span></h3>")
display(VBox([sampled_trajectories_label, accepted_designs_label]))

# initialise counters
script_start_time = time.time()
trajectory_n = 1
accepted_designs = 0

### start design loop
while True:
    ### check if we have the target number of binders
    final_designs_reached = check_accepted_designs(design_paths, mpnn_csv, final_labels, final_csv, advanced_settings, target_settings, design_labels)

    if final_designs_reached:
        # stop design loop execution
        break

    ### check if we reached maximum allowed trajectories
    max_trajectories_reached = check_n_trajectories(design_paths, advanced_settings)

    if max_trajectories_reached:
        break

    ### Initialise design
    # measure time to generate design
    trajectory_start_time = time.time()

    # generate random seed to vary designs
    seed = int(np.random.randint(0, high=999999, size=1, dtype=int)[0])

    # sample binder design length randomly from defined distribution
    samples = np.arange(min(target_settings["lengths"]), max(target_settings["lengths"]) + 1)
    length = np.random.choice(samples)

    # load desired helicity value to sample different secondary structure contents
    helicity_value = load_helicity(advanced_settings)

    # generate design name and check if same trajectory was already run
    design_name = target_settings["binder_name"] + "_l" + str(length) + "_s"+ str(seed)
    trajectory_dirs = ["Trajectory", "Trajectory/Relaxed", "Trajectory/LowConfidence", "Trajectory/Clashing"]
    trajectory_exists = any(os.path.exists(os.path.join(design_paths[trajectory_dir], design_name + ".pdb")) for trajectory_dir in trajectory_dirs)

    if not trajectory_exists:
        print("Starting trajectory: "+design_name)

        ### Begin binder hallucination
        trajectory = binder_hallucination(design_name, target_settings["starting_pdb"], target_settings["chains"],
                                            target_settings["target_hotspot_residues"], length, seed, helicity_value,
                                            design_models, advanced_settings, design_paths, failure_csv)
        trajectory_metrics = copy_dict(trajectory.aux["log"]) # contains plddt, ptm, i_ptm, pae, i_pae
        trajectory_pdb = os.path.join(design_paths["Trajectory"], design_name + ".pdb")

        # round the metrics to two decimal places
        trajectory_metrics = {k: round(v, 2) if isinstance(v, float) else v for k, v in trajectory_metrics.items()}

        # time trajectory
        trajectory_time = time.time() - trajectory_start_time
        trajectory_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(trajectory_time // 3600), int((trajectory_time % 3600) // 60), int(trajectory_time % 60))}"
        print("Starting trajectory took: "+trajectory_time_text)
        print("")

        # Proceed if there is no trajectory termination signal
        if trajectory_metrics['terminate'] == "":
            # Relax binder to calculate statistics
            trajectory_relaxed = os.path.join(design_paths["Trajectory/Relaxed"], design_name + ".pdb")
            pr_relax(trajectory_pdb, trajectory_relaxed)

            # define binder chain, placeholder in case multi-chain parsing in ColabDesign gets changed
            binder_chain = "B"

            # Calculate clashes before and after relaxation
            num_clashes_trajectory = calculate_clash_score(trajectory_pdb)
            num_clashes_relaxed = calculate_clash_score(trajectory_relaxed)

            # secondary structure content of starting trajectory binder and interface
            trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_i_plddt, trajectory_ss_plddt = calc_ss_percentage(trajectory_pdb, advanced_settings, binder_chain)

            # analyze interface scores for relaxed af2 trajectory
            trajectory_interface_scores, trajectory_interface_AA, trajectory_interface_residues = score_interface(trajectory_relaxed, binder_chain)

            # starting binder sequence
            trajectory_sequence = trajectory.get_seq(get_best=True)[0]

            # analyze sequence
            traj_seq_notes = validate_design_sequence(trajectory_sequence, num_clashes_relaxed, advanced_settings)

            # target structure RMSD compared to input PDB
            trajectory_target_rmsd = unaligned_rmsd(target_settings["starting_pdb"], trajectory_pdb, target_settings["chains"], 'A')

            # save trajectory statistics into CSV
            trajectory_data = [design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], trajectory_sequence, trajectory_interface_residues,
                                trajectory_metrics['plddt'], trajectory_metrics['ptm'], trajectory_metrics['i_ptm'], trajectory_metrics['pae'], trajectory_metrics['i_pae'],
                                trajectory_i_plddt, trajectory_ss_plddt, num_clashes_trajectory, num_clashes_relaxed, trajectory_interface_scores['binder_score'],
                                trajectory_interface_scores['surface_hydrophobicity'], trajectory_interface_scores['interface_sc'], trajectory_interface_scores['interface_packstat'],
                                trajectory_interface_scores['interface_dG'], trajectory_interface_scores['interface_dSASA'], trajectory_interface_scores['interface_dG_SASA_ratio'],
                                trajectory_interface_scores['interface_fraction'], trajectory_interface_scores['interface_hydrophobicity'], trajectory_interface_scores['interface_nres'], trajectory_interface_scores['interface_interface_hbonds'],
                                trajectory_interface_scores['interface_hbond_percentage'], trajectory_interface_scores['interface_delta_unsat_hbonds'], trajectory_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_interface_AA, trajectory_target_rmsd,
                                trajectory_time_text, traj_seq_notes, settings_file, filters_file, advanced_file]
            insert_data(trajectory_csv, trajectory_data)

            if advanced_settings["enable_mpnn"]:
                # initialise MPNN counters
                mpnn_n = 1
                accepted_mpnn = 0
                mpnn_dict = {}
                design_start_time = time.time()

                ### MPNN redesign of starting binder
                mpnn_trajectories = mpnn_gen_sequence(trajectory_pdb, binder_chain, trajectory_interface_residues, advanced_settings)
                existing_mpnn_sequences = set(pd.read_csv(mpnn_csv, usecols=['Sequence'])['Sequence'].values)

                # create set of MPNN sequences with allowed amino acid composition
                restricted_AAs = set(aa.strip().upper() for aa in advanced_settings["omit_AAs"].split(',')) if advanced_settings["force_reject_AA"] else set()

                mpnn_sequences = sorted({
                    mpnn_trajectories['seq'][n][-length:]: {
                        'seq': mpnn_trajectories['seq'][n][-length:],
                        'score': mpnn_trajectories['score'][n],
                        'seqid': mpnn_trajectories['seqid'][n]
                    } for n in range(advanced_settings["num_seqs"])
                    if (not restricted_AAs or not any(aa in mpnn_trajectories['seq'][n][-length:].upper() for aa in restricted_AAs))
                    and mpnn_trajectories['seq'][n][-length:] not in existing_mpnn_sequences
                }.values(), key=lambda x: x['score'])

                del existing_mpnn_sequences

                # check whether any sequences are left after amino acid rejection and duplication check, and if yes proceed with prediction
                if mpnn_sequences:
                    # add optimisation for increasing recycles if trajectory is beta sheeted
                    if advanced_settings["optimise_beta"] and float(trajectory_beta) > 15:
                        advanced_settings["num_recycles_validation"] = advanced_settings["optimise_beta_recycles_valid"]

                    ### Compile prediction models once for faster prediction of MPNN sequences
                    clear_mem()
                    # compile complex prediction model
                    complex_prediction_model = mk_afdesign_model(protocol="binder", num_recycles=advanced_settings["num_recycles_validation"], data_dir=advanced_settings["af_params_dir"],
                                                                use_multimer=multimer_validation)
                    complex_prediction_model.prep_inputs(pdb_filename=target_settings["starting_pdb"], chain=target_settings["chains"], binder_len=length, rm_target_seq=advanced_settings["rm_template_seq_predict"],
                                                        rm_target_sc=advanced_settings["rm_template_sc_predict"])

                    # compile binder monomer prediction model
                    binder_prediction_model = mk_afdesign_model(protocol="hallucination", use_templates=False, initial_guess=False,
                                                                use_initial_atom_pos=False, num_recycles=advanced_settings["num_recycles_validation"],
                                                                data_dir=advanced_settings["af_params_dir"], use_multimer=multimer_validation)
                    binder_prediction_model.prep_inputs(length=length)

                    # iterate over designed sequences
                    for mpnn_sequence in mpnn_sequences:
                        mpnn_time = time.time()

                        # generate mpnn design name numbering
                        mpnn_design_name = design_name + "_mpnn" + str(mpnn_n)
                        mpnn_score = round(mpnn_sequence['score'],2)
                        mpnn_seqid = round(mpnn_sequence['seqid'],2)

                        # add design to dictionary
                        mpnn_dict[mpnn_design_name] = {'seq': mpnn_sequence['seq'], 'score': mpnn_score, 'seqid': mpnn_seqid}

                        # save fasta sequence
                        if advanced_settings["save_mpnn_fasta"] is True:
                            save_fasta(mpnn_design_name, mpnn_sequence['seq'], design_paths)

                        ### Predict mpnn redesigned binder complex using masked templates
                        mpnn_complex_statistics, pass_af2_filters = masked_binder_predict(complex_prediction_model,
                                                                                        mpnn_sequence['seq'], mpnn_design_name,
                                                                                        target_settings["starting_pdb"], target_settings["chains"],
                                                                                        length, trajectory_pdb, prediction_models, advanced_settings,
                                                                                        filters, design_paths, failure_csv)

                        # if AF2 filters are not passed then skip the scoring
                        if not pass_af2_filters:
                            print(f"Base AF2 filters not passed for {mpnn_design_name}, skipping interface scoring")
                            mpnn_n += 1
                            continue

                        # calculate statistics for each model individually
                        for model_num in prediction_models:
                            mpnn_design_pdb = os.path.join(design_paths["MPNN"], f"{mpnn_design_name}_model{model_num+1}.pdb")
                            mpnn_design_relaxed = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_design_pdb):
                                # Calculate clashes before and after relaxation
                                num_clashes_mpnn = calculate_clash_score(mpnn_design_pdb)
                                num_clashes_mpnn_relaxed = calculate_clash_score(mpnn_design_relaxed)

                                # analyze interface scores for relaxed af2 trajectory
                                mpnn_interface_scores, mpnn_interface_AA, mpnn_interface_residues = score_interface(mpnn_design_relaxed, binder_chain)

                                # secondary structure content of starting trajectory binder
                                mpnn_alpha, mpnn_beta, mpnn_loops, mpnn_alpha_interface, mpnn_beta_interface, mpnn_loops_interface, mpnn_i_plddt, mpnn_ss_plddt = calc_ss_percentage(mpnn_design_pdb, advanced_settings, binder_chain)

                                # unaligned RMSD calculate to determine if binder is in the designed binding site
                                rmsd_site = unaligned_rmsd(trajectory_pdb, mpnn_design_pdb, binder_chain, binder_chain)

                                # calculate RMSD of target compared to input PDB
                                target_rmsd = target_pdb_rmsd(mpnn_design_pdb, target_settings["starting_pdb"], target_settings["chains"])

                                # add the additional statistics to the mpnn_complex_statistics dictionary
                                mpnn_complex_statistics[model_num+1].update({
                                    'i_pLDDT': mpnn_i_plddt,
                                    'ss_pLDDT': mpnn_ss_plddt,
                                    'Unrelaxed_Clashes': num_clashes_mpnn,
                                    'Relaxed_Clashes': num_clashes_mpnn_relaxed,
                                    'Binder_Energy_Score': mpnn_interface_scores['binder_score'],
                                    'Surface_Hydrophobicity': mpnn_interface_scores['surface_hydrophobicity'],
                                    'ShapeComplementarity': mpnn_interface_scores['interface_sc'],
                                    'PackStat': mpnn_interface_scores['interface_packstat'],
                                    'dG': mpnn_interface_scores['interface_dG'],
                                    'dSASA': mpnn_interface_scores['interface_dSASA'],
                                    'dG/dSASA': mpnn_interface_scores['interface_dG_SASA_ratio'],
                                    'Interface_SASA_%': mpnn_interface_scores['interface_fraction'],
                                    'Interface_Hydrophobicity': mpnn_interface_scores['interface_hydrophobicity'],
                                    'n_InterfaceResidues': mpnn_interface_scores['interface_nres'],
                                    'n_InterfaceHbonds': mpnn_interface_scores['interface_interface_hbonds'],
                                    'InterfaceHbondsPercentage': mpnn_interface_scores['interface_hbond_percentage'],
                                    'n_InterfaceUnsatHbonds': mpnn_interface_scores['interface_delta_unsat_hbonds'],
                                    'InterfaceUnsatHbondsPercentage': mpnn_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                    'InterfaceAAs': mpnn_interface_AA,
                                    'Interface_Helix%': mpnn_alpha_interface,
                                    'Interface_BetaSheet%': mpnn_beta_interface,
                                    'Interface_Loop%': mpnn_loops_interface,
                                    'Binder_Helix%': mpnn_alpha,
                                    'Binder_BetaSheet%': mpnn_beta,
                                    'Binder_Loop%': mpnn_loops,
                                    'Hotspot_RMSD': rmsd_site,
                                    'Target_RMSD': target_rmsd
                                })

                                # save space by removing unrelaxed predicted mpnn complex pdb?
                                if advanced_settings["remove_unrelaxed_complex"]:
                                    os.remove(mpnn_design_pdb)

                        # calculate complex averages
                        mpnn_complex_averages = calculate_averages(mpnn_complex_statistics, handle_aa=True)

                        ### Predict binder alone in single sequence mode
                        binder_statistics = predict_binder_alone(binder_prediction_model, mpnn_sequence['seq'], mpnn_design_name, length,
                                                                trajectory_pdb, binder_chain, prediction_models, advanced_settings, design_paths)

                        # extract RMSDs of binder to the original trajectory
                        for model_num in prediction_models:
                            mpnn_binder_pdb = os.path.join(design_paths["MPNN/Binder"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_binder_pdb):
                                rmsd_binder = unaligned_rmsd(trajectory_pdb, mpnn_binder_pdb, binder_chain, "A")

                            # append to statistics
                            binder_statistics[model_num+1].update({
                                    'Binder_RMSD': rmsd_binder
                                })

                            # save space by removing binder monomer models?
                            if advanced_settings["remove_binder_monomer"]:
                                os.remove(mpnn_binder_pdb)

                        # calculate binder averages
                        binder_averages = calculate_averages(binder_statistics)

                        # analyze sequence to make sure there are no cysteins and it contains residues that absorb UV for detection
                        seq_notes = validate_design_sequence(mpnn_sequence['seq'], mpnn_complex_averages.get('Relaxed_Clashes', None), advanced_settings)

                        # measure time to generate design
                        mpnn_end_time = time.time() - mpnn_time
                        elapsed_mpnn_text = f"{'%d hours, %d minutes, %d seconds' % (int(mpnn_end_time // 3600), int((mpnn_end_time % 3600) // 60), int(mpnn_end_time % 60))}"


                        # Insert statistics about MPNN design into CSV, will return None if corresponding model does note exist
                        model_numbers = range(1, 6)
                        statistics_labels = ['pLDDT', 'pTM', 'i_pTM', 'pAE', 'i_pAE', 'i_pLDDT', 'ss_pLDDT', 'Unrelaxed_Clashes', 'Relaxed_Clashes', 'Binder_Energy_Score', 'Surface_Hydrophobicity',
                                            'ShapeComplementarity', 'PackStat', 'dG', 'dSASA', 'dG/dSASA', 'Interface_SASA_%', 'Interface_Hydrophobicity', 'n_InterfaceResidues', 'n_InterfaceHbonds', 'InterfaceHbondsPercentage',
                                            'n_InterfaceUnsatHbonds', 'InterfaceUnsatHbondsPercentage', 'Interface_Helix%', 'Interface_BetaSheet%', 'Interface_Loop%', 'Binder_Helix%',
                                            'Binder_BetaSheet%', 'Binder_Loop%', 'InterfaceAAs', 'Hotspot_RMSD', 'Target_RMSD']

                        # Initialize mpnn_data with the non-statistical data
                        mpnn_data = [mpnn_design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], mpnn_sequence['seq'], mpnn_interface_residues, mpnn_score, mpnn_seqid]

                        # Add the statistical data for mpnn_complex
                        for label in statistics_labels:
                            mpnn_data.append(mpnn_complex_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(mpnn_complex_statistics.get(model, {}).get(label, None))

                        # Add the statistical data for binder
                        for label in ['pLDDT', 'pTM', 'pAE', 'Binder_RMSD']:  # These are the labels for binder alone
                            mpnn_data.append(binder_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(binder_statistics.get(model, {}).get(label, None))

                        # Add the remaining non-statistical data
                        mpnn_data.extend([elapsed_mpnn_text, seq_notes, settings_file, filters_file, advanced_file])

                        # insert data into csv
                        insert_data(mpnn_csv, mpnn_data)

                        # find best model number by pLDDT
                        plddt_values = {i: mpnn_data[i] for i in range(11, 15) if mpnn_data[i] is not None}

                        # Find the key with the highest value
                        highest_plddt_key = int(max(plddt_values, key=plddt_values.get))

                        # Output the number part of the key
                        best_model_number = highest_plddt_key - 10
                        best_model_pdb = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{best_model_number}.pdb")

                        # run design data against filter thresholds
                        filter_conditions = check_filters(mpnn_data, design_labels, filters)
                        if filter_conditions == True:
                            print(mpnn_design_name+" passed all filters")
                            accepted_mpnn += 1
                            accepted_designs += 1

                            # copy designs to accepted folder
                            shutil.copy(best_model_pdb, design_paths["Accepted"])

                            # insert data into final csv
                            final_data = [''] + mpnn_data
                            insert_data(final_csv, final_data)

                            # copy animation from accepted trajectory
                            if advanced_settings["save_design_animations"]:
                                accepted_animation = os.path.join(design_paths["Accepted/Animation"], f"{design_name}.html")
                                if not os.path.exists(accepted_animation):
                                    shutil.copy(os.path.join(design_paths["Trajectory/Animation"], f"{design_name}.html"), accepted_animation)

                            # copy plots of accepted trajectory
                            plot_files = os.listdir(design_paths["Trajectory/Plots"])
                            plots_to_copy = [f for f in plot_files if f.startswith(design_name) and f.endswith('.png')]
                            for accepted_plot in plots_to_copy:
                                source_plot = os.path.join(design_paths["Trajectory/Plots"], accepted_plot)
                                target_plot = os.path.join(design_paths["Accepted/Plots"], accepted_plot)
                                if not os.path.exists(target_plot):
                                    shutil.copy(source_plot, target_plot)

                        else:
                            print(f"Unmet filter conditions for {mpnn_design_name}")
                            failure_df = pd.read_csv(failure_csv)
                            special_prefixes = ('Average_', '1_', '2_', '3_', '4_', '5_')
                            incremented_columns = set()

                            for column in filter_conditions:
                                base_column = column
                                for prefix in special_prefixes:
                                    if column.startswith(prefix):
                                        base_column = column.split('_', 1)[1]

                                if base_column not in incremented_columns:
                                    failure_df[base_column] = failure_df[base_column] + 1
                                    incremented_columns.add(base_column)

                            failure_df.to_csv(failure_csv, index=False)
                            shutil.copy(best_model_pdb, design_paths["Rejected"])

                        # increase MPNN design number
                        mpnn_n += 1

                        # if enough mpnn sequences of the same trajectory pass filters then stop
                        if accepted_mpnn >= advanced_settings["max_mpnn_sequences"]:
                            break

                    if accepted_mpnn >= 1:
                        print("Found "+str(accepted_mpnn)+" MPNN designs passing filters")
                    else:
                        print("No accepted MPNN designs found for this trajectory.")

                else:
                    print('Duplicate MPNN designs sampled with different trajectory, skipping current trajectory optimisation')

                # save space by removing unrelaxed design trajectory PDB
                if advanced_settings["remove_unrelaxed_trajectory"]:
                    os.remove(trajectory_pdb)

                # measure time it took to generate designs for one trajectory
                design_time = time.time() - design_start_time
                design_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(design_time // 3600), int((design_time % 3600) // 60), int(design_time % 60))}"
                print("Design and validation of trajectory "+design_name+" took: "+design_time_text)

            # analyse the rejection rate of trajectories to see if we need to readjust the design weights
            if trajectory_n >= advanced_settings["start_monitoring"] and advanced_settings["enable_rejection_check"]:
                acceptance = accepted_designs / trajectory_n
                if not acceptance >= advanced_settings["acceptance_rate"]:
                    print("The ratio of successful designs is lower than defined acceptance rate! Consider changing your design settings!")
                    print("Script execution stopping...")
                    break

        # increase trajectory number
        trajectory_n += 1

        # Colab-specific: update counters
        num_sampled_trajectories = len(pd.read_csv(trajectory_csv))
        num_accepted_designs = len(pd.read_csv(final_csv))
        sampled_trajectories_label.value = f"Sampled trajectories: {num_sampled_trajectories}"
        accepted_designs_label.value = f"Accepted designs: {num_accepted_designs}"

### Script finished
elapsed_time = time.time() - script_start_time
elapsed_text = f"{'%d hours, %d minutes, %d seconds' % (int(elapsed_time // 3600), int((elapsed_time % 3600) // 60), int(elapsed_time % 60))}"
print("Finished all designs. Script execution for "+str(trajectory_n)+" trajectories took: "+elapsed_text)
# Out:
# VBox(children=(HTML(value="<h3 style='color: #1f77b4;'>Sampled Trajectories: <span style='color: #1f77b4;'>1</…
# Starting trajectory: PDL1_l25_s799940
# Starting SKINIT!
# Stage 1: Test Logits
# 1 models [3] recycles 1 hard 0 soft 0.02 temp 1 loss 9.25 helix 1.80 pae 0.63 i_pae 0.66 con 4.69 i_con 3.83 plddt 0.36 ptm 0.75 i_ptm 0.19 rg 2.87
# 2 models [1] recycles 1 hard 0 soft 0.04 temp 1 loss 10.18 helix 2.42 pae 0.70 i_pae 0.74 con 5.07 i_con 4.12 plddt 0.28 ptm 0.73 i_ptm 0.12 rg 4.11
# 3 models [2] recycles 1 hard 0 soft 0.05 temp 1 loss 8.87 helix 1.82 pae 0.64 i_pae 0.68 con 4.61 i_con 3.86 plddt 0.32 ptm 0.73 i_ptm 0.17 rg 1.70
# 4 models [2] recycles 1 hard 0 soft 0.07 temp 1 loss 8.80 helix 1.53 pae 0.62 i_pae 0.65 con 4.57 i_con 3.77 plddt 0.35 ptm 0.72 i_ptm 0.18 rg 1.67
# 5 models [2] recycles 1 hard 0 soft 0.09 temp 1 loss 8.40 helix 1.45 pae 0.59 i_pae 0.63 con 4.33 i_con 3.69 plddt 0.36 ptm 0.74 i_ptm 0.20 rg 1.36
# 6 models [1] recycles 1 hard 0 soft 0.11 temp 1 loss 8.01 helix 1.45 pae 0.56 i_pae 0.59 con 4.22 i_con 3.71 plddt 0.39 ptm 0.75 i_ptm 0.23 rg 0.45
# 7 models [4] recycles 1 hard 0 soft 0.13 temp 1 loss 7.63 helix 1.36 pae 0.56 i_pae 0.60 con 3.96 i_con 3.58 plddt 0.42 ptm 0.75 i_ptm 0.25 rg 0.38
# 8 models [1] recycles 1 hard 0 soft 0.14 temp 1 loss 7.59 helix 1.33 pae 0.52 i_pae 0.56 con 3.88 i_con 3.61 plddt 0.44 ptm 0.75 i_ptm 0.25 rg 0.48
# 9 models [3] recycles 1 hard 0 soft 0.16 temp 1 loss 7.73 helix 1.24 pae 0.54 i_pae 0.58 con 3.97 i_con 3.58 plddt 0.45 ptm 0.75 i_ptm 0.25 rg 0.59
# 10 models [4] recycles 1 hard 0 soft 0.18 temp 1 loss 7.67 helix 1.23 pae 0.55 i_pae 0.59 con 3.87 i_con 3.61 plddt 0.45 ptm 0.75 i_ptm 0.22 rg 0.64
# 11 models [4] recycles 1 hard 0 soft 0.20 temp 1 loss 7.56 helix 1.24 pae 0.51 i_pae 0.55 con 3.79 i_con 3.48 plddt 0.48 ptm 0.75 i_ptm 0.28 rg 1.04
# 12 models [1] recycles 1 hard 0 soft 0.22 temp 1 loss 7.39 helix 1.27 pae 0.49 i_pae 0.53 con 3.71 i_con 3.54 plddt 0.47 ptm 0.76 i_ptm 0.28 rg 0.60
# 13 models [1] recycles 1 hard 0 soft 0.23 temp 1 loss 7.21 helix 1.27 pae 0.51 i_pae 0.55 con 3.65 i_con 3.55 plddt 0.45 ptm 0.76 i_ptm 0.26 rg 0.16
# 14 models [1] recycles 1 hard 0 soft 0.25 temp 1 loss 7.22 helix 1.26 pae 0.49 i_pae 0.54 con 3.59 i_con 3.54 plddt 0.48 ptm 0.76 i_ptm 0.26 rg 0.41
# 15 models [1] recycles 1 hard 0 soft 0.27 temp 1 loss 7.10 helix 1.19 pae 0.50 i_pae 0.55 con 3.50 i_con 3.51 plddt 0.49 ptm 0.75 i_ptm 0.25 rg 0.35
# 16 models [0] recycles 1 hard 0 soft 0.29 temp 1 loss 7.33 helix 1.27 pae 0.52 i_pae 0.57 con 3.64 i_con 3.59 plddt 0.44 ptm 0.74 i_ptm 0.24 rg 0.42
# 17 models [4] recycles 1 hard 0 soft 0.31 temp 1 loss 7.22 helix 1.30 pae 0.53 i_pae 0.58 con 3.56 i_con 3.55 plddt 0.46 ptm 0.75 i_ptm 0.24 rg 0.48
# 18 models [2] recycles 1 hard 0 soft 0.32 temp 1 loss 7.32 helix 1.28 pae 0.56 i_pae 0.61 con 3.69 i_con 3.63 plddt 0.43 ptm 0.74 i_ptm 0.21 rg 0.00
# 19 models [0] recycles 1 hard 0 soft 0.34 temp 1 loss 6.75 helix 1.36 pae 0.48 i_pae 0.53 con 3.25 i_con 3.52 plddt 0.50 ptm 0.75 i_ptm 0.28 rg 0.16
# 20 models [4] recycles 1 hard 0 soft 0.36 temp 1 loss 6.95 helix 1.29 pae 0.51 i_pae 0.55 con 3.50 i_con 3.51 plddt 0.47 ptm 0.75 i_ptm 0.25 rg -0.11
# 21 models [1] recycles 1 hard 0 soft 0.38 temp 1 loss 6.86 helix 1.23 pae 0.46 i_pae 0.51 con 3.37 i_con 3.43 plddt 0.51 ptm 0.75 i_ptm 0.30 rg 0.36
# 22 models [4] recycles 1 hard 0 soft 0.40 temp 1 loss 6.89 helix 1.07 pae 0.50 i_pae 0.55 con 3.41 i_con 3.48 plddt 0.48 ptm 0.75 i_ptm 0.24 rg -0.06
# 23 models [1] recycles 1 hard 0 soft 0.41 temp 1 loss 6.87 helix 1.16 pae 0.47 i_pae 0.53 con 3.35 i_con 3.52 plddt 0.51 ptm 0.75 i_ptm 0.26 rg 0.06
# 24 models [0] recycles 1 hard 0 soft 0.43 temp 1 loss 6.72 helix 1.28 pae 0.47 i_pae 0.52 con 3.17 i_con 3.49 plddt 0.52 ptm 0.75 i_ptm 0.29 rg 0.39
# 25 models [3] recycles 1 hard 0 soft 0.45 temp 1 loss 7.25 helix 1.27 pae 0.54 i_pae 0.59 con 3.57 i_con 3.60 plddt 0.44 ptm 0.75 i_ptm 0.22 rg 0.33
# 26 models [1] recycles 1 hard 0 soft 0.47 temp 1 loss 6.62 helix 1.17 pae 0.43 i_pae 0.47 con 3.27 i_con 3.33 plddt 0.55 ptm 0.77 i_ptm 0.33 rg 0.26
# 27 models [4] recycles 1 hard 0 soft 0.49 temp 1 loss 6.79 helix 1.19 pae 0.48 i_pae 0.53 con 3.30 i_con 3.48 plddt 0.50 ptm 0.75 i_ptm 0.27 rg 0.14
# 28 models [4] recycles 1 hard 0 soft 0.50 temp 1 loss 6.42 helix 1.25 pae 0.41 i_pae 0.44 con 3.12 i_con 3.27 plddt 0.59 ptm 0.77 i_ptm 0.40 rg 0.43
# 29 models [3] recycles 1 hard 0 soft 0.52 temp 1 loss 6.56 helix 1.38 pae 0.44 i_pae 0.48 con 3.18 i_con 3.30 plddt 0.57 ptm 0.77 i_ptm 0.37 rg 0.68
# 30 models [4] recycles 1 hard 0 soft 0.54 temp 1 loss 6.73 helix 1.17 pae 0.45 i_pae 0.49 con 3.18 i_con 3.39 plddt 0.56 ptm 0.77 i_ptm 0.34 rg 0.68
# 31 models [2] recycles 1 hard 0 soft 0.56 temp 1 loss 7.22 helix 1.27 pae 0.54 i_pae 0.59 con 3.50 i_con 3.66 plddt 0.46 ptm 0.73 i_ptm 0.23 rg 0.25
# 32 models [1] recycles 1 hard 0 soft 0.58 temp 1 loss 6.80 helix 1.31 pae 0.47 i_pae 0.51 con 3.35 i_con 3.46 plddt 0.53 ptm 0.76 i_ptm 0.30 rg 0.22
# 33 models [3] recycles 1 hard 0 soft 0.59 temp 1 loss 6.86 helix 1.41 pae 0.51 i_pae 0.57 con 3.24 i_con 3.60 plddt 0.50 ptm 0.74 i_ptm 0.24 rg 0.32
# 34 models [4] recycles 1 hard 0 soft 0.61 temp 1 loss 7.11 helix 1.22 pae 0.53 i_pae 0.59 con 3.48 i_con 3.61 plddt 0.46 ptm 0.75 i_ptm 0.23 rg 0.11
# 35 models [4] recycles 1 hard 0 soft 0.63 temp 1 loss 6.82 helix 1.36 pae 0.53 i_pae 0.59 con 3.34 i_con 3.58 plddt 0.48 ptm 0.74 i_ptm 0.21 rg -0.14
# 36 models [3] recycles 1 hard 0 soft 0.65 temp 1 loss 6.94 helix 1.37 pae 0.51 i_pae 0.56 con 3.36 i_con 3.55 plddt 0.47 ptm 0.75 i_ptm 0.24 rg 0.27
# 37 models [1] recycles 1 hard 0 soft 0.67 temp 1 loss 6.96 helix 1.28 pae 0.47 i_pae 0.51 con 3.51 i_con 3.49 plddt 0.50 ptm 0.76 i_ptm 0.29 rg 0.08
# 38 models [1] recycles 1 hard 0 soft 0.68 temp 1 loss 6.75 helix 1.16 pae 0.48 i_pae 0.54 con 3.26 i_con 3.52 plddt 0.48 ptm 0.76 i_ptm 0.25 rg -0.07
# 39 models [0] recycles 1 hard 0 soft 0.70 temp 1 loss 6.80 helix 1.31 pae 0.49 i_pae 0.53 con 3.23 i_con 3.51 plddt 0.49 ptm 0.75 i_ptm 0.26 rg 0.42
# 40 models [2] recycles 1 hard 0 soft 0.72 temp 1 loss 7.05 helix 1.42 pae 0.53 i_pae 0.58 con 3.37 i_con 3.61 plddt 0.48 ptm 0.73 i_ptm 0.22 rg 0.43
# 41 models [1] recycles 1 hard 0 soft 0.74 temp 1 loss 6.70 helix 1.22 pae 0.47 i_pae 0.52 con 3.28 i_con 3.45 plddt 0.52 ptm 0.76 i_ptm 0.27 rg 0.06
# 42 models [2] recycles 1 hard 0 soft 0.76 temp 1 loss 7.19 helix 1.17 pae 0.52 i_pae 0.57 con 3.52 i_con 3.58 plddt 0.48 ptm 0.74 i_ptm 0.22 rg 0.27
# 43 models [3] recycles 1 hard 0 soft 0.77 temp 1 loss 7.03 helix 1.30 pae 0.50 i_pae 0.55 con 3.49 i_con 3.50 plddt 0.49 ptm 0.75 i_ptm 0.25 rg 0.30
# 44 models [1] recycles 1 hard 0 soft 0.79 temp 1 loss 6.68 helix 1.16 pae 0.42 i_pae 0.46 con 3.36 i_con 3.29 plddt 0.57 ptm 0.77 i_ptm 0.37 rg 0.29
# 45 models [4] recycles 1 hard 0 soft 0.81 temp 1 loss 6.57 helix 1.18 pae 0.44 i_pae 0.49 con 3.19 i_con 3.32 plddt 0.55 ptm 0.77 i_ptm 0.35 rg 0.34
# 46 models [3] recycles 1 hard 0 soft 0.83 temp 1 loss 6.04 helix 1.41 pae 0.36 i_pae 0.39 con 2.99 i_con 3.01 plddt 0.65 ptm 0.80 i_ptm 0.52 rg 0.74
# 47 models [1] recycles 1 hard 0 soft 0.85 temp 1 loss 6.57 helix 1.22 pae 0.42 i_pae 0.46 con 3.22 i_con 3.33 plddt 0.57 ptm 0.78 i_ptm 0.36 rg 0.33
# 48 models [2] recycles 1 hard 0 soft 0.86 temp 1 loss 7.38 helix 1.33 pae 0.48 i_pae 0.52 con 3.70 i_con 3.45 plddt 0.51 ptm 0.76 i_ptm 0.34 rg 1.01
# 49 models [4] recycles 1 hard 0 soft 0.88 temp 1 loss 6.70 helix 1.22 pae 0.43 i_pae 0.46 con 3.35 i_con 3.26 plddt 0.56 ptm 0.77 i_ptm 0.38 rg 0.55
# 50 models [0] recycles 1 hard 0 soft 0.90 temp 1 loss 6.73 helix 1.30 pae 0.48 i_pae 0.53 con 3.24 i_con 3.52 plddt 0.49 ptm 0.75 i_ptm 0.26 rg 0.06
# Initial trajectory pLDDT too low to continue: 0.65
# Trajectory starting confidence low, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 2 minutes, 7 seconds
#
# Starting trajectory: PDL1_l25_s439769
# Starting SKINIT!
# Stage 1: Test Logits
# 1 models [3] recycles 1 hard 0 soft 0.02 temp 1 loss 9.72 helix 2.02 pae 0.66 i_pae 0.70 con 4.85 i_con 3.91 plddt 0.33 ptm 0.73 i_ptm 0.16 rg 3.73
# 2 models [1] recycles 1 hard 0 soft 0.04 temp 1 loss 9.56 helix 1.86 pae 0.64 i_pae 0.67 con 4.77 i_con 3.92 plddt 0.33 ptm 0.73 i_ptm 0.18 rg 3.34
# 3 models [1] recycles 1 hard 0 soft 0.05 temp 1 loss 8.92 helix 1.84 pae 0.62 i_pae 0.65 con 4.62 i_con 3.89 plddt 0.35 ptm 0.74 i_ptm 0.19 rg 1.81
# 4 models [3] recycles 1 hard 0 soft 0.07 temp 1 loss 8.35 helix 1.59 pae 0.60 i_pae 0.63 con 4.42 i_con 3.75 plddt 0.38 ptm 0.75 i_ptm 0.20 rg 0.85
# 5 models [0] recycles 1 hard 0 soft 0.09 temp 1 loss 7.96 helix 1.46 pae 0.55 i_pae 0.59 con 4.13 i_con 3.66 plddt 0.42 ptm 0.74 i_ptm 0.22 rg 0.75
# 6 models [1] recycles 1 hard 0 soft 0.11 temp 1 loss 8.14 helix 1.61 pae 0.56 i_pae 0.60 con 4.25 i_con 3.70 plddt 0.41 ptm 0.75 i_ptm 0.22 rg 0.95
# 7 models [2] recycles 1 hard 0 soft 0.13 temp 1 loss 8.14 helix 1.40 pae 0.59 i_pae 0.64 con 4.26 i_con 3.71 plddt 0.40 ptm 0.73 i_ptm 0.19 rg 0.65
# 8 models [2] recycles 1 hard 0 soft 0.14 temp 1 loss 8.14 helix 1.44 pae 0.58 i_pae 0.62 con 4.22 i_con 3.67 plddt 0.39 ptm 0.74 i_ptm 0.21 rg 0.98
# 9 models [1] recycles 1 hard 0 soft 0.16 temp 1 loss 7.81 helix 1.46 pae 0.52 i_pae 0.57 con 4.08 i_con 3.63 plddt 0.44 ptm 0.75 i_ptm 0.25 rg 0.61
# 10 models [4] recycles 1 hard 0 soft 0.18 temp 1 loss 7.70 helix 1.49 pae 0.53 i_pae 0.57 con 3.89 i_con 3.52 plddt 0.44 ptm 0.75 i_ptm 0.24 rg 1.22
# 11 models [0] recycles 1 hard 0 soft 0.20 temp 1 loss 7.68 helix 1.53 pae 0.54 i_pae 0.59 con 3.95 i_con 3.66 plddt 0.43 ptm 0.74 i_ptm 0.22 rg 0.50
# 12 models [4] recycles 1 hard 0 soft 0.22 temp 1 loss 7.65 helix 1.47 pae 0.54 i_pae 0.59 con 3.91 i_con 3.54 plddt 0.45 ptm 0.75 i_ptm 0.23 rg 0.91
# 13 models [4] recycles 1 hard 0 soft 0.23 temp 1 loss 7.38 helix 1.49 pae 0.50 i_pae 0.54 con 3.79 i_con 3.45 plddt 0.48 ptm 0.75 i_ptm 0.27 rg 0.84
# 14 models [3] recycles 1 hard 0 soft 0.25 temp 1 loss 7.91 helix 1.41 pae 0.55 i_pae 0.60 con 3.99 i_con 3.60 plddt 0.44 ptm 0.75 i_ptm 0.22 rg 1.21
# 15 models [4] recycles 1 hard 0 soft 0.27 temp 1 loss 7.63 helix 1.34 pae 0.54 i_pae 0.59 con 4.02 i_con 3.54 plddt 0.43 ptm 0.75 i_ptm 0.24 rg 0.34
# 16 models [1] recycles 1 hard 0 soft 0.29 temp 1 loss 7.53 helix 1.38 pae 0.50 i_pae 0.54 con 3.91 i_con 3.49 plddt 0.47 ptm 0.76 i_ptm 0.27 rg 0.66
# 17 models [0] recycles 1 hard 0 soft 0.31 temp 1 loss 7.53 helix 1.40 pae 0.51 i_pae 0.55 con 3.85 i_con 3.52 plddt 0.45 ptm 0.74 i_ptm 0.25 rg 0.77
# 18 models [3] recycles 1 hard 0 soft 0.32 temp 1 loss 7.50 helix 1.48 pae 0.53 i_pae 0.57 con 3.89 i_con 3.50 plddt 0.44 ptm 0.75 i_ptm 0.25 rg 0.63
# 19 models [1] recycles 1 hard 0 soft 0.34 temp 1 loss 7.42 helix 1.51 pae 0.50 i_pae 0.55 con 3.85 i_con 3.49 plddt 0.47 ptm 0.75 i_ptm 0.25 rg 0.66
# 20 models [2] recycles 1 hard 0 soft 0.36 temp 1 loss 7.55 helix 1.41 pae 0.53 i_pae 0.58 con 3.84 i_con 3.57 plddt 0.43 ptm 0.74 i_ptm 0.23 rg 0.64
# 21 models [4] recycles 1 hard 0 soft 0.38 temp 1 loss 7.34 helix 1.45 pae 0.52 i_pae 0.58 con 3.71 i_con 3.54 plddt 0.48 ptm 0.75 i_ptm 0.24 rg 0.55
# 22 models [2] recycles 1 hard 0 soft 0.40 temp 1 loss 7.46 helix 1.47 pae 0.53 i_pae 0.58 con 3.81 i_con 3.56 plddt 0.46 ptm 0.74 i_ptm 0.23 rg 0.56
# 23 models [0] recycles 1 hard 0 soft 0.41 temp 1 loss 7.23 helix 1.52 pae 0.53 i_pae 0.57 con 3.80 i_con 3.57 plddt 0.43 ptm 0.76 i_ptm 0.23 rg -0.19
# 24 models [4] recycles 1 hard 0 soft 0.43 temp 1 loss 6.64 helix 1.67 pae 0.47 i_pae 0.52 con 3.43 i_con 3.36 plddt 0.48 ptm 0.76 i_ptm 0.30 rg 0.07
# 25 models [4] recycles 1 hard 0 soft 0.45 temp 1 loss 6.82 helix 1.66 pae 0.47 i_pae 0.52 con 3.52 i_con 3.36 plddt 0.51 ptm 0.76 i_ptm 0.28 rg 0.37
# 26 models [0] recycles 1 hard 0 soft 0.47 temp 1 loss 7.11 helix 1.59 pae 0.50 i_pae 0.55 con 3.64 i_con 3.48 plddt 0.48 ptm 0.75 i_ptm 0.25 rg 0.42
# 27 models [1] recycles 1 hard 0 soft 0.49 temp 1 loss 7.31 helix 1.50 pae 0.48 i_pae 0.53 con 3.71 i_con 3.44 plddt 0.48 ptm 0.75 i_ptm 0.26 rg 0.88
# 28 models [3] recycles 1 hard 0 soft 0.50 temp 1 loss 6.81 helix 1.90 pae 0.48 i_pae 0.53 con 3.37 i_con 3.40 plddt 0.53 ptm 0.76 i_ptm 0.28 rg 0.92
# 29 models [1] recycles 1 hard 0 soft 0.52 temp 1 loss 6.93 helix 1.66 pae 0.49 i_pae 0.53 con 3.51 i_con 3.45 plddt 0.47 ptm 0.76 i_ptm 0.28 rg 0.41
# 30 models [0] recycles 1 hard 0 soft 0.54 temp 1 loss 7.36 helix 1.52 pae 0.47 i_pae 0.52 con 3.63 i_con 3.44 plddt 0.44 ptm 0.76 i_ptm 0.30 rg 1.35
# 31 models [4] recycles 1 hard 0 soft 0.56 temp 1 loss 7.03 helix 1.51 pae 0.47 i_pae 0.51 con 3.52 i_con 3.34 plddt 0.51 ptm 0.76 i_ptm 0.29 rg 1.02
# 32 models [3] recycles 1 hard 0 soft 0.58 temp 1 loss 7.10 helix 1.71 pae 0.51 i_pae 0.56 con 3.53 i_con 3.55 plddt 0.48 ptm 0.74 i_ptm 0.23 rg 0.62
# 33 models [2] recycles 1 hard 0 soft 0.59 temp 1 loss 7.44 helix 1.42 pae 0.53 i_pae 0.59 con 3.72 i_con 3.57 plddt 0.45 ptm 0.73 i_ptm 0.22 rg 0.73
# 34 models [1] recycles 1 hard 0 soft 0.61 temp 1 loss 6.48 helix 1.94 pae 0.48 i_pae 0.53 con 3.35 i_con 3.42 plddt 0.51 ptm 0.76 i_ptm 0.25 rg -0.13
# 35 models [1] recycles 1 hard 0 soft 0.63 temp 1 loss 7.75 helix 1.28 pae 0.52 i_pae 0.56 con 4.09 i_con 3.57 plddt 0.42 ptm 0.75 i_ptm 0.25 rg 0.40
# 36 models [0] recycles 1 hard 0 soft 0.65 temp 1 loss 7.03 helix 1.48 pae 0.50 i_pae 0.54 con 3.62 i_con 3.49 plddt 0.46 ptm 0.75 i_ptm 0.26 rg 0.09
# 37 models [4] recycles 1 hard 0 soft 0.67 temp 1 loss 6.86 helix 1.62 pae 0.50 i_pae 0.55 con 3.45 i_con 3.46 plddt 0.50 ptm 0.76 i_ptm 0.25 rg 0.30
# 38 models [0] recycles 1 hard 0 soft 0.68 temp 1 loss 6.49 helix 1.87 pae 0.49 i_pae 0.55 con 3.32 i_con 3.44 plddt 0.50 ptm 0.74 i_ptm 0.24 rg -0.16
# 39 models [1] recycles 1 hard 0 soft 0.70 temp 1 loss 7.93 helix 1.48 pae 0.54 i_pae 0.57 con 4.09 i_con 3.59 plddt 0.40 ptm 0.75 i_ptm 0.24 rg 1.10
# 40 models [0] recycles 1 hard 0 soft 0.72 temp 1 loss 7.77 helix 1.50 pae 0.53 i_pae 0.57 con 4.05 i_con 3.56 plddt 0.41 ptm 0.75 i_ptm 0.23 rg 0.82
# 41 models [1] recycles 1 hard 0 soft 0.74 temp 1 loss 8.03 helix 1.37 pae 0.52 i_pae 0.56 con 4.17 i_con 3.55 plddt 0.42 ptm 0.76 i_ptm 0.25 rg 1.20
# 42 models [4] recycles 1 hard 0 soft 0.76 temp 1 loss 7.08 helix 1.41 pae 0.51 i_pae 0.56 con 3.72 i_con 3.45 plddt 0.46 ptm 0.76 i_ptm 0.25 rg -0.09
# 43 models [4] recycles 1 hard 0 soft 0.77 temp 1 loss 6.72 helix 1.72 pae 0.50 i_pae 0.56 con 3.40 i_con 3.42 plddt 0.51 ptm 0.75 i_ptm 0.24 rg 0.22
# 44 models [2] recycles 1 hard 0 soft 0.79 temp 1 loss 7.26 helix 1.60 pae 0.52 i_pae 0.57 con 3.74 i_con 3.54 plddt 0.48 ptm 0.74 i_ptm 0.23 rg 0.35
# 45 models [4] recycles 1 hard 0 soft 0.81 temp 1 loss 7.03 helix 1.49 pae 0.53 i_pae 0.58 con 3.74 i_con 3.47 plddt 0.46 ptm 0.75 i_ptm 0.23 rg -0.31
# 46 models [2] recycles 1 hard 0 soft 0.83 temp 1 loss 6.80 helix 1.82 pae 0.42 i_pae 0.46 con 3.55 i_con 3.22 plddt 0.57 ptm 0.75 i_ptm 0.35 rg 0.98
# 47 models [2] recycles 1 hard 0 soft 0.85 temp 1 loss 6.85 helix 1.73 pae 0.51 i_pae 0.56 con 3.47 i_con 3.53 plddt 0.49 ptm 0.74 i_ptm 0.24 rg 0.10
# 48 models [4] recycles 1 hard 0 soft 0.86 temp 1 loss 6.69 helix 1.70 pae 0.45 i_pae 0.50 con 3.42 i_con 3.29 plddt 0.54 ptm 0.76 i_ptm 0.30 rg 0.58
# 49 models [4] recycles 1 hard 0 soft 0.88 temp 1 loss 6.73 helix 1.73 pae 0.49 i_pae 0.55 con 3.45 i_con 3.41 plddt 0.52 ptm 0.75 i_ptm 0.25 rg 0.17
# 50 models [2] recycles 1 hard 0 soft 0.90 temp 1 loss 6.90 helix 1.78 pae 0.48 i_pae 0.53 con 3.52 i_con 3.41 plddt 0.51 ptm 0.74 i_ptm 0.28 rg 0.56
# Initial trajectory pLDDT too low to continue: 0.51
# Trajectory starting confidence low, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 1 minutes, 57 seconds
#
# Starting trajectory: PDL1_l25_s96186
# Starting SKINIT!
# Stage 1: Test Logits
# 1 models [0] recycles 1 hard 0 soft 0.02 temp 1 loss 8.81 helix 1.92 pae 0.62 i_pae 0.65 con 4.52 i_con 3.85 plddt 0.33 ptm 0.74 i_ptm 0.18 rg 1.96
# 2 models [1] recycles 1 hard 0 soft 0.04 temp 1 loss 9.71 helix 1.94 pae 0.65 i_pae 0.68 con 4.83 i_con 3.96 plddt 0.34 ptm 0.74 i_ptm 0.17 rg 3.55
# 3 models [3] recycles 1 hard 0 soft 0.05 temp 1 loss 9.10 helix 1.76 pae 0.63 i_pae 0.66 con 4.64 i_con 3.81 plddt 0.35 ptm 0.74 i_ptm 0.19 rg 2.55
# 4 models [4] recycles 1 hard 0 soft 0.07 temp 1 loss 8.73 helix 1.58 pae 0.61 i_pae 0.64 con 4.55 i_con 3.70 plddt 0.36 ptm 0.75 i_ptm 0.19 rg 1.82
# 5 models [1] recycles 1 hard 0 soft 0.09 temp 1 loss 8.48 helix 1.78 pae 0.60 i_pae 0.63 con 4.55 i_con 3.77 plddt 0.35 ptm 0.75 i_ptm 0.20 rg 0.96
# 6 models [3] recycles 1 hard 0 soft 0.11 temp 1 loss 8.12 helix 1.60 pae 0.58 i_pae 0.61 con 4.23 i_con 3.63 plddt 0.38 ptm 0.75 i_ptm 0.22 rg 1.15
# 7 models [4] recycles 1 hard 0 soft 0.13 temp 1 loss 7.93 helix 1.55 pae 0.56 i_pae 0.60 con 4.14 i_con 3.61 plddt 0.39 ptm 0.75 i_ptm 0.23 rg 0.84
# 8 models [4] recycles 1 hard 0 soft 0.14 temp 1 loss 7.82 helix 1.44 pae 0.56 i_pae 0.60 con 4.13 i_con 3.64 plddt 0.40 ptm 0.75 i_ptm 0.22 rg 0.32
# 9 models [1] recycles 1 hard 0 soft 0.16 temp 1 loss 7.79 helix 1.47 pae 0.50 i_pae 0.55 con 4.00 i_con 3.57 plddt 0.45 ptm 0.76 i_ptm 0.26 rg 1.05
# 10 models [1] recycles 1 hard 0 soft 0.18 temp 1 loss 7.49 helix 1.51 pae 0.50 i_pae 0.54 con 3.84 i_con 3.52 plddt 0.46 ptm 0.76 i_ptm 0.26 rg 0.78
# 11 models [2] recycles 1 hard 0 soft 0.20 temp 1 loss 7.84 helix 1.44 pae 0.57 i_pae 0.62 con 3.97 i_con 3.66 plddt 0.44 ptm 0.73 i_ptm 0.19 rg 0.86
# 12 models [3] recycles 1 hard 0 soft 0.22 temp 1 loss 7.59 helix 1.37 pae 0.55 i_pae 0.60 con 3.97 i_con 3.61 plddt 0.44 ptm 0.75 i_ptm 0.21 rg 0.16
# 13 models [0] recycles 1 hard 0 soft 0.23 temp 1 loss 7.76 helix 1.31 pae 0.54 i_pae 0.59 con 3.98 i_con 3.66 plddt 0.42 ptm 0.74 i_ptm 0.21 rg 0.45
# 14 models [3] recycles 1 hard 0 soft 0.25 temp 1 loss 7.84 helix 1.40 pae 0.55 i_pae 0.60 con 3.93 i_con 3.62 plddt 0.45 ptm 0.74 i_ptm 0.22 rg 1.09
# 15 models [4] recycles 1 hard 0 soft 0.27 temp 1 loss 7.72 helix 1.24 pae 0.55 i_pae 0.60 con 4.00 i_con 3.59 plddt 0.45 ptm 0.74 i_ptm 0.22 rg 0.43
# 16 models [3] recycles 1 hard 0 soft 0.29 temp 1 loss 7.69 helix 1.36 pae 0.54 i_pae 0.59 con 3.92 i_con 3.60 plddt 0.47 ptm 0.74 i_ptm 0.21 rg 0.70
# 17 models [1] recycles 1 hard 0 soft 0.31 temp 1 loss 7.47 helix 1.42 pae 0.49 i_pae 0.54 con 3.85 i_con 3.54 plddt 0.49 ptm 0.75 i_ptm 0.27 rg 0.57
# 18 models [1] recycles 1 hard 0 soft 0.32 temp 1 loss 7.46 helix 1.36 pae 0.52 i_pae 0.57 con 3.88 i_con 3.60 plddt 0.46 ptm 0.75 i_ptm 0.24 rg 0.08
# 19 models [4] recycles 1 hard 0 soft 0.34 temp 1 loss 7.44 helix 1.39 pae 0.53 i_pae 0.58 con 3.88 i_con 3.54 plddt 0.44 ptm 0.75 i_ptm 0.22 rg 0.26
# 20 models [0] recycles 1 hard 0 soft 0.36 temp 1 loss 7.44 helix 1.38 pae 0.38 i_pae 0.40 con 3.86 i_con 3.06 plddt 0.49 ptm 0.79 i_ptm 0.45 rg 2.21
# 21 models [3] recycles 1 hard 0 soft 0.38 temp 1 loss 7.51 helix 1.43 pae 0.55 i_pae 0.60 con 3.85 i_con 3.60 plddt 0.44 ptm 0.74 i_ptm 0.21 rg 0.39
# 22 models [1] recycles 1 hard 0 soft 0.40 temp 1 loss 7.43 helix 1.41 pae 0.52 i_pae 0.57 con 3.87 i_con 3.59 plddt 0.46 ptm 0.75 i_ptm 0.23 rg 0.11
# 23 models [4] recycles 1 hard 0 soft 0.41 temp 1 loss 7.47 helix 1.44 pae 0.53 i_pae 0.58 con 3.82 i_con 3.59 plddt 0.47 ptm 0.74 i_ptm 0.22 rg 0.45
# 24 models [1] recycles 1 hard 0 soft 0.43 temp 1 loss 7.26 helix 1.44 pae 0.50 i_pae 0.54 con 3.80 i_con 3.53 plddt 0.46 ptm 0.76 i_ptm 0.25 rg 0.04
# 25 models [0] recycles 1 hard 0 soft 0.45 temp 1 loss 7.29 helix 1.43 pae 0.51 i_pae 0.56 con 3.80 i_con 3.56 plddt 0.47 ptm 0.74 i_ptm 0.23 rg 0.03
# 26 models [1] recycles 1 hard 0 soft 0.47 temp 1 loss 7.24 helix 1.45 pae 0.52 i_pae 0.58 con 3.76 i_con 3.58 plddt 0.46 ptm 0.75 i_ptm 0.23 rg -0.07
# 27 models [1] recycles 1 hard 0 soft 0.49 temp 1 loss 7.27 helix 1.46 pae 0.50 i_pae 0.55 con 3.71 i_con 3.59 plddt 0.48 ptm 0.75 i_ptm 0.26 rg 0.23
# 28 models [2] recycles 1 hard 0 soft 0.50 temp 1 loss 7.53 helix 1.31 pae 0.56 i_pae 0.62 con 3.76 i_con 3.66 plddt 0.45 ptm 0.73 i_ptm 0.19 rg 0.44
# 29 models [2] recycles 1 hard 0 soft 0.52 temp 1 loss 7.44 helix 1.35 pae 0.55 i_pae 0.60 con 3.76 i_con 3.63 plddt 0.45 ptm 0.74 i_ptm 0.21 rg 0.28
# 30 models [4] recycles 1 hard 0 soft 0.54 temp 1 loss 6.93 helix 1.43 pae 0.48 i_pae 0.52 con 3.61 i_con 3.37 plddt 0.49 ptm 0.76 i_ptm 0.31 rg 0.15
# 31 models [2] recycles 1 hard 0 soft 0.56 temp 1 loss 7.19 helix 1.42 pae 0.53 i_pae 0.58 con 3.67 i_con 3.60 plddt 0.45 ptm 0.73 i_ptm 0.23 rg -0.07
# 32 models [4] recycles 1 hard 0 soft 0.58 temp 1 loss 6.98 helix 1.40 pae 0.51 i_pae 0.56 con 3.59 i_con 3.54 plddt 0.46 ptm 0.75 i_ptm 0.26 rg -0.23
# 33 models [4] recycles 1 hard 0 soft 0.59 temp 1 loss 6.48 helix 1.54 pae 0.47 i_pae 0.51 con 3.24 i_con 3.38 plddt 0.52 ptm 0.76 i_ptm 0.31 rg -0.00
# 34 models [3] recycles 1 hard 0 soft 0.61 temp 1 loss 6.49 helix 1.66 pae 0.50 i_pae 0.55 con 3.15 i_con 3.48 plddt 0.51 ptm 0.75 i_ptm 0.27 rg 0.06
# 35 models [4] recycles 1 hard 0 soft 0.63 temp 1 loss 6.48 helix 1.54 pae 0.46 i_pae 0.51 con 3.23 i_con 3.38 plddt 0.54 ptm 0.76 i_ptm 0.32 rg 0.06
# 36 models [3] recycles 1 hard 0 soft 0.65 temp 1 loss 6.60 helix 1.55 pae 0.49 i_pae 0.54 con 3.25 i_con 3.45 plddt 0.50 ptm 0.76 i_ptm 0.28 rg 0.09
# 37 models [3] recycles 1 hard 0 soft 0.67 temp 1 loss 6.38 helix 1.51 pae 0.46 i_pae 0.50 con 3.32 i_con 3.32 plddt 0.45 ptm 0.77 i_ptm 0.34 rg -0.43
# 38 models [4] recycles 1 hard 0 soft 0.68 temp 1 loss 6.40 helix 1.50 pae 0.47 i_pae 0.51 con 3.23 i_con 3.36 plddt 0.51 ptm 0.76 i_ptm 0.31 rg -0.20
# 39 models [0] recycles 1 hard 0 soft 0.70 temp 1 loss 6.56 helix 1.57 pae 0.47 i_pae 0.52 con 3.27 i_con 3.50 plddt 0.49 ptm 0.76 i_ptm 0.28 rg -0.21
# 40 models [3] recycles 1 hard 0 soft 0.72 temp 1 loss 5.86 helix 1.80 pae 0.40 i_pae 0.44 con 2.87 i_con 3.14 plddt 0.61 ptm 0.78 i_ptm 0.41 rg 0.38
# 41 models [3] recycles 1 hard 0 soft 0.74 temp 1 loss 6.38 helix 1.77 pae 0.50 i_pae 0.55 con 3.26 i_con 3.43 plddt 0.49 ptm 0.76 i_ptm 0.27 rg -0.39
# 42 models [0] recycles 1 hard 0 soft 0.76 temp 1 loss 6.54 helix 1.82 pae 0.48 i_pae 0.52 con 3.37 i_con 3.49 plddt 0.48 ptm 0.75 i_ptm 0.28 rg -0.38
# 43 models [3] recycles 1 hard 0 soft 0.77 temp 1 loss 6.14 helix 1.74 pae 0.43 i_pae 0.47 con 3.02 i_con 3.29 plddt 0.58 ptm 0.77 i_ptm 0.36 rg 0.20
# 44 models [4] recycles 1 hard 0 soft 0.79 temp 1 loss 6.48 helix 1.64 pae 0.49 i_pae 0.53 con 3.35 i_con 3.41 plddt 0.49 ptm 0.76 i_ptm 0.30 rg -0.40
# 45 models [0] recycles 1 hard 0 soft 0.81 temp 1 loss 6.00 helix 1.65 pae 0.46 i_pae 0.51 con 2.85 i_con 3.41 plddt 0.53 ptm 0.75 i_ptm 0.28 rg -0.24
# 46 models [1] recycles 1 hard 0 soft 0.83 temp 1 loss 5.93 helix 1.86 pae 0.44 i_pae 0.49 con 2.87 i_con 3.42 plddt 0.55 ptm 0.77 i_ptm 0.30 rg -0.37
# 47 models [4] recycles 1 hard 0 soft 0.85 temp 1 loss 5.86 helix 1.68 pae 0.41 i_pae 0.46 con 2.93 i_con 3.24 plddt 0.49 ptm 0.78 i_ptm 0.36 rg -0.33
# 48 models [3] recycles 1 hard 0 soft 0.86 temp 1 loss 6.40 helix 1.59 pae 0.50 i_pae 0.55 con 3.10 i_con 3.47 plddt 0.51 ptm 0.75 i_ptm 0.25 rg -0.09
# 49 models [4] recycles 1 hard 0 soft 0.88 temp 1 loss 6.26 helix 1.76 pae 0.47 i_pae 0.52 con 3.14 i_con 3.40 plddt 0.53 ptm 0.76 i_ptm 0.29 rg -0.22
# 50 models [2] recycles 1 hard 0 soft 0.90 temp 1 loss 6.17 helix 1.59 pae 0.48 i_pae 0.54 con 2.87 i_con 3.46 plddt 0.53 ptm 0.75 i_ptm 0.27 rg -0.06
# Initial trajectory pLDDT too low to continue: 0.61
# Trajectory starting confidence low, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 2 minutes, 1 seconds
#
# Starting trajectory: PDL1_l25_s160002
# Starting SKINIT!
# Stage 1: Test Logits
# 1 models [3] recycles 1 hard 0 soft 0.02 temp 1 loss 8.60 helix 1.89 pae 0.64 i_pae 0.67 con 4.74 i_con 3.86 plddt 0.33 ptm 0.73 i_ptm 0.19 rg 0.48
# 2 models [2] recycles 1 hard 0 soft 0.04 temp 1 loss 9.00 helix 1.83 pae 0.64 i_pae 0.67 con 4.63 i_con 3.84 plddt 0.34 ptm 0.73 i_ptm 0.17 rg 2.20
# 3 models [2] recycles 1 hard 0 soft 0.05 temp 1 loss 8.54 helix 1.76 pae 0.64 i_pae 0.68 con 4.61 i_con 3.85 plddt 0.33 ptm 0.72 i_ptm 0.17 rg 0.60
# 4 models [4] recycles 1 hard 0 soft 0.07 temp 1 loss 8.64 helix 1.67 pae 0.60 i_pae 0.63 con 4.46 i_con 3.70 plddt 0.35 ptm 0.75 i_ptm 0.22 rg 1.92
# 5 models [0] recycles 1 hard 0 soft 0.09 temp 1 loss 8.07 helix 1.55 pae 0.58 i_pae 0.61 con 4.30 i_con 3.71 plddt 0.36 ptm 0.73 i_ptm 0.20 rg 0.42
# 6 models [2] recycles 1 hard 0 soft 0.11 temp 1 loss 8.27 helix 1.52 pae 0.60 i_pae 0.64 con 4.45 i_con 3.73 plddt 0.35 ptm 0.74 i_ptm 0.19 rg 0.46
# 7 models [0] recycles 1 hard 0 soft 0.13 temp 1 loss 8.07 helix 1.44 pae 0.57 i_pae 0.61 con 4.25 i_con 3.71 plddt 0.38 ptm 0.74 i_ptm 0.21 rg 0.48
# 8 models [2] recycles 1 hard 0 soft 0.14 temp 1 loss 8.49 helix 1.49 pae 0.60 i_pae 0.64 con 4.34 i_con 3.76 plddt 0.39 ptm 0.73 i_ptm 0.19 rg 1.39
# 9 models [2] recycles 1 hard 0 soft 0.16 temp 1 loss 8.14 helix 1.46 pae 0.58 i_pae 0.63 con 4.13 i_con 3.73 plddt 0.42 ptm 0.73 i_ptm 0.20 rg 1.08
# 10 models [0] recycles 1 hard 0 soft 0.18 temp 1 loss 7.59 helix 1.54 pae 0.55 i_pae 0.59 con 3.97 i_con 3.64 plddt 0.42 ptm 0.74 i_ptm 0.22 rg 0.22
# 11 models [4] recycles 1 hard 0 soft 0.20 temp 1 loss 7.76 helix 1.38 pae 0.53 i_pae 0.57 con 4.01 i_con 3.49 plddt 0.47 ptm 0.75 i_ptm 0.25 rg 1.06
# 12 models [0] recycles 1 hard 0 soft 0.22 temp 1 loss 7.60 helix 1.55 pae 0.53 i_pae 0.58 con 3.87 i_con 3.56 plddt 0.44 ptm 0.75 i_ptm 0.22 rg 0.90
# 13 models [3] recycles 1 hard 0 soft 0.23 temp 1 loss 7.83 helix 1.52 pae 0.56 i_pae 0.60 con 4.04 i_con 3.61 plddt 0.43 ptm 0.74 i_ptm 0.23 rg 0.88
# 14 models [0] recycles 1 hard 0 soft 0.25 temp 1 loss 7.57 helix 1.60 pae 0.53 i_pae 0.58 con 4.01 i_con 3.59 plddt 0.43 ptm 0.75 i_ptm 0.23 rg 0.28
# 15 models [4] recycles 1 hard 0 soft 0.27 temp 1 loss 7.55 helix 1.46 pae 0.52 i_pae 0.57 con 3.82 i_con 3.48 plddt 0.47 ptm 0.75 i_ptm 0.25 rg 1.11
# 16 models [2] recycles 1 hard 0 soft 0.29 temp 1 loss 7.51 helix 1.53 pae 0.54 i_pae 0.58 con 3.86 i_con 3.55 plddt 0.44 ptm 0.74 i_ptm 0.24 rg 0.63
# 17 models [4] recycles 1 hard 0 soft 0.31 temp 1 loss 7.38 helix 1.47 pae 0.50 i_pae 0.54 con 3.78 i_con 3.44 plddt 0.48 ptm 0.75 i_ptm 0.28 rg 0.85
# 18 models [2] recycles 1 hard 0 soft 0.32 temp 1 loss 7.74 helix 1.49 pae 0.53 i_pae 0.57 con 3.83 i_con 3.53 plddt 0.47 ptm 0.75 i_ptm 0.25 rg 1.56
# 19 models [0] recycles 1 hard 0 soft 0.34 temp 1 loss 7.42 helix 1.51 pae 0.51 i_pae 0.56 con 3.81 i_con 3.53 plddt 0.45 ptm 0.75 i_ptm 0.25 rg 0.58
# 20 models [0] recycles 1 hard 0 soft 0.36 temp 1 loss 7.02 helix 1.63 pae 0.46 i_pae 0.50 con 3.65 i_con 3.38 plddt 0.45 ptm 0.76 i_ptm 0.29 rg 0.52
# 21 models [2] recycles 1 hard 0 soft 0.38 temp 1 loss 7.14 helix 1.67 pae 0.52 i_pae 0.57 con 3.69 i_con 3.49 plddt 0.47 ptm 0.74 i_ptm 0.23 rg 0.36
# 22 models [2] recycles 1 hard 0 soft 0.40 temp 1 loss 7.07 helix 1.68 pae 0.50 i_pae 0.55 con 3.63 i_con 3.44 plddt 0.49 ptm 0.74 i_ptm 0.26 rg 0.52
# 23 models [0] recycles 1 hard 0 soft 0.41 temp 1 loss 6.11 helix 1.90 pae 0.38 i_pae 0.42 con 3.42 i_con 3.14 plddt 0.46 ptm 0.77 i_ptm 0.41 rg -0.56
# 24 models [2] recycles 1 hard 0 soft 0.43 temp 1 loss 7.10 helix 1.65 pae 0.50 i_pae 0.55 con 3.66 i_con 3.50 plddt 0.48 ptm 0.74 i_ptm 0.24 rg 0.32
# 25 models [1] recycles 1 hard 0 soft 0.45 temp 1 loss 6.61 helix 1.86 pae 0.43 i_pae 0.47 con 3.41 i_con 3.32 plddt 0.55 ptm 0.76 i_ptm 0.33 rg 0.44
# 26 models [3] recycles 1 hard 0 soft 0.47 temp 1 loss 6.81 helix 1.83 pae 0.50 i_pae 0.56 con 3.54 i_con 3.49 plddt 0.49 ptm 0.75 i_ptm 0.25 rg -0.04
# 27 models [1] recycles 1 hard 0 soft 0.49 temp 1 loss 6.50 helix 1.80 pae 0.47 i_pae 0.52 con 3.36 i_con 3.39 plddt 0.51 ptm 0.75 i_ptm 0.26 rg -0.08
# 28 models [2] recycles 1 hard 0 soft 0.50 temp 1 loss 6.84 helix 1.65 pae 0.50 i_pae 0.55 con 3.52 i_con 3.47 plddt 0.51 ptm 0.74 i_ptm 0.24 rg 0.02
# 29 models [1] recycles 1 hard 0 soft 0.52 temp 1 loss 6.53 helix 1.85 pae 0.44 i_pae 0.49 con 3.43 i_con 3.33 plddt 0.52 ptm 0.76 i_ptm 0.30 rg 0.06
# 30 models [2] recycles 1 hard 0 soft 0.54 temp 1 loss 6.90 helix 1.73 pae 0.50 i_pae 0.55 con 3.59 i_con 3.46 plddt 0.48 ptm 0.73 i_ptm 0.24 rg 0.06
# 31 models [1] recycles 1 hard 0 soft 0.56 temp 1 loss 6.33 helix 1.94 pae 0.39 i_pae 0.43 con 3.33 i_con 3.17 plddt 0.58 ptm 0.78 i_ptm 0.37 rg 0.47
# 32 models [3] recycles 1 hard 0 soft 0.58 temp 1 loss 6.52 helix 1.82 pae 0.42 i_pae 0.46 con 3.39 i_con 3.23 plddt 0.58 ptm 0.77 i_ptm 0.38 rg 0.53
# 33 models [1] recycles 1 hard 0 soft 0.59 temp 1 loss 6.39 helix 1.87 pae 0.38 i_pae 0.42 con 3.37 i_con 3.11 plddt 0.61 ptm 0.78 i_ptm 0.40 rg 0.72
# 34 models [1] recycles 1 hard 0 soft 0.61 temp 1 loss 6.56 helix 1.80 pae 0.46 i_pae 0.51 con 3.40 i_con 3.37 plddt 0.52 ptm 0.76 i_ptm 0.29 rg 0.02
# 35 models [3] recycles 1 hard 0 soft 0.63 temp 1 loss 6.56 helix 1.87 pae 0.38 i_pae 0.42 con 3.43 i_con 3.14 plddt 0.64 ptm 0.78 i_ptm 0.44 rg 0.97
# 36 models [1] recycles 1 hard 0 soft 0.65 temp 1 loss 6.67 helix 1.82 pae 0.42 i_pae 0.46 con 3.41 i_con 3.34 plddt 0.56 ptm 0.76 i_ptm 0.34 rg 0.58
# 37 models [4] recycles 1 hard 0 soft 0.67 temp 1 loss 5.83 helix 1.95 pae 0.29 i_pae 0.32 con 3.19 i_con 2.79 plddt 0.72 ptm 0.81 i_ptm 0.60 rg 0.81
# 38 models [2] recycles 1 hard 0 soft 0.68 temp 1 loss 5.36 helix 1.97 pae 0.25 i_pae 0.27 con 3.06 i_con 2.51 plddt 0.78 ptm 0.82 i_ptm 0.69 rg 0.70
# 39 models [1] recycles 1 hard 0 soft 0.70 temp 1 loss 5.74 helix 2.02 pae 0.24 i_pae 0.26 con 3.39 i_con 2.43 plddt 0.76 ptm 0.84 i_ptm 0.69 rg 1.23
# 40 models [3] recycles 1 hard 0 soft 0.72 temp 1 loss 4.89 helix 2.26 pae 0.23 i_pae 0.24 con 2.98 i_con 2.19 plddt 0.82 ptm 0.84 i_ptm 0.75 rg 0.85
# 41 models [4] recycles 1 hard 0 soft 0.74 temp 1 loss 4.99 helix 2.20 pae 0.23 i_pae 0.24 con 3.04 i_con 2.26 plddt 0.82 ptm 0.85 i_ptm 0.75 rg 0.67
# 42 models [2] recycles 1 hard 0 soft 0.76 temp 1 loss 5.38 helix 1.93 pae 0.25 i_pae 0.27 con 3.15 i_con 2.40 plddt 0.79 ptm 0.83 i_ptm 0.71 rg 0.81
# 43 models [2] recycles 1 hard 0 soft 0.77 temp 1 loss 4.97 helix 2.14 pae 0.23 i_pae 0.24 con 3.01 i_con 2.24 plddt 0.81 ptm 0.83 i_ptm 0.75 rg 0.70
# 44 models [4] recycles 1 hard 0 soft 0.79 temp 1 loss 5.08 helix 2.31 pae 0.23 i_pae 0.24 con 3.06 i_con 2.28 plddt 0.82 ptm 0.84 i_ptm 0.74 rg 0.94
# 45 models [0] recycles 1 hard 0 soft 0.81 temp 1 loss 5.15 helix 2.06 pae 0.24 i_pae 0.26 con 3.00 i_con 2.43 plddt 0.77 ptm 0.83 i_ptm 0.70 rg 0.60
# 46 models [2] recycles 1 hard 0 soft 0.83 temp 1 loss 5.96 helix 1.88 pae 0.29 i_pae 0.31 con 3.35 i_con 2.70 plddt 0.73 ptm 0.81 i_ptm 0.62 rg 0.94
# 47 models [4] recycles 1 hard 0 soft 0.85 temp 1 loss 5.08 helix 2.27 pae 0.23 i_pae 0.24 con 3.06 i_con 2.28 plddt 0.82 ptm 0.85 i_ptm 0.75 rg 0.94
# 48 models [1] recycles 1 hard 0 soft 0.86 temp 1 loss 5.08 helix 2.15 pae 0.22 i_pae 0.23 con 3.12 i_con 2.19 plddt 0.80 ptm 0.85 i_ptm 0.75 rg 0.93
# 49 models [0] recycles 1 hard 0 soft 0.88 temp 1 loss 5.00 helix 2.09 pae 0.23 i_pae 0.25 con 3.00 i_con 2.25 plddt 0.80 ptm 0.84 i_ptm 0.74 rg 0.76
# 50 models [3] recycles 1 hard 0 soft 0.90 temp 1 loss 4.91 helix 2.22 pae 0.23 i_pae 0.24 con 2.94 i_con 2.25 plddt 0.81 ptm 0.84 i_ptm 0.75 rg 0.80
# Initial trajectory pLDDT good, continuing: 0.82
# Stage 1: Additional Logits Optimisation
# 51 models [0] recycles 1 hard 0 soft 0.04 temp 1 loss 5.04 helix 2.08 pae 0.23 i_pae 0.24 con 2.98 i_con 2.31 plddt 0.80 ptm 0.84 i_ptm 0.73 rg 0.75
# 52 models [0] recycles 1 hard 0 soft 0.08 temp 1 loss 4.94 helix 2.02 pae 0.22 i_pae 0.24 con 2.94 i_con 2.24 plddt 0.81 ptm 0.84 i_ptm 0.75 rg 0.74
# 53 models [1] recycles 1 hard 0 soft 0.12 temp 1 loss 4.66 helix 2.16 pae 0.21 i_pae 0.22 con 2.87 i_con 2.13 plddt 0.82 ptm 0.85 i_ptm 0.78 rg 0.59
# 54 models [4] recycles 1 hard 0 soft 0.16 temp 1 loss 5.26 helix 1.94 pae 0.24 i_pae 0.26 con 3.00 i_con 2.47 plddt 0.79 ptm 0.83 i_ptm 0.72 rg 0.71
# 55 models [2] recycles 1 hard 0 soft 0.20 temp 1 loss 4.93 helix 2.04 pae 0.23 i_pae 0.24 con 2.99 i_con 2.22 plddt 0.80 ptm 0.84 i_ptm 0.74 rg 0.65
# 56 models [2] recycles 1 hard 0 soft 0.24 temp 1 loss 4.93 helix 2.13 pae 0.22 i_pae 0.24 con 3.00 i_con 2.20 plddt 0.82 ptm 0.84 i_ptm 0.76 rg 0.76
# 57 models [0] recycles 1 hard 0 soft 0.28 temp 1 loss 4.73 helix 2.17 pae 0.22 i_pae 0.23 con 2.87 i_con 2.18 plddt 0.82 ptm 0.85 i_ptm 0.76 rg 0.65
# 58 models [3] recycles 1 hard 0 soft 0.32 temp 1 loss 4.61 helix 2.12 pae 0.22 i_pae 0.23 con 2.78 i_con 2.17 plddt 0.83 ptm 0.85 i_ptm 0.77 rg 0.54
# 59 models [0] recycles 1 hard 0 soft 0.36 temp 1 loss 4.67 helix 2.13 pae 0.22 i_pae 0.23 con 2.86 i_con 2.11 plddt 0.81 ptm 0.84 i_ptm 0.76 rg 0.66
# 60 models [0] recycles 1 hard 0 soft 0.40 temp 1 loss 4.86 helix 2.07 pae 0.22 i_pae 0.24 con 2.85 i_con 2.32 plddt 0.80 ptm 0.84 i_ptm 0.73 rg 0.54
# 61 models [3] recycles 1 hard 0 soft 0.44 temp 1 loss 4.47 helix 2.25 pae 0.21 i_pae 0.22 con 2.77 i_con 2.06 plddt 0.84 ptm 0.85 i_ptm 0.78 rg 0.62
# 62 models [0] recycles 1 hard 0 soft 0.48 temp 1 loss 4.80 helix 2.23 pae 0.23 i_pae 0.24 con 2.86 i_con 2.26 plddt 0.81 ptm 0.83 i_ptm 0.74 rg 0.67
# 63 models [1] recycles 1 hard 0 soft 0.52 temp 1 loss 4.64 helix 2.32 pae 0.21 i_pae 0.22 con 2.79 i_con 2.23 plddt 0.80 ptm 0.84 i_ptm 0.75 rg 0.60
# 64 models [2] recycles 1 hard 0 soft 0.56 temp 1 loss 5.22 helix 2.10 pae 0.25 i_pae 0.26 con 3.01 i_con 2.44 plddt 0.79 ptm 0.82 i_ptm 0.70 rg 0.79
# 65 models [2] recycles 1 hard 0 soft 0.60 temp 1 loss 4.78 helix 2.42 pae 0.22 i_pae 0.23 con 2.92 i_con 2.20 plddt 0.83 ptm 0.84 i_ptm 0.76 rg 0.80
# 66 models [2] recycles 1 hard 0 soft 0.64 temp 1 loss 4.73 helix 2.53 pae 0.22 i_pae 0.23 con 2.93 i_con 2.21 plddt 0.82 ptm 0.84 i_ptm 0.75 rg 0.71
# 67 models [3] recycles 1 hard 0 soft 0.68 temp 1 loss 4.80 helix 2.51 pae 0.22 i_pae 0.23 con 2.94 i_con 2.20 plddt 0.82 ptm 0.84 i_ptm 0.75 rg 0.90
# 68 models [3] recycles 1 hard 0 soft 0.72 temp 1 loss 4.54 helix 2.60 pae 0.20 i_pae 0.22 con 2.83 i_con 2.10 plddt 0.84 ptm 0.85 i_ptm 0.77 rg 0.85
# 69 models [2] recycles 1 hard 0 soft 0.76 temp 1 loss 4.96 helix 2.42 pae 0.23 i_pae 0.25 con 3.00 i_con 2.29 plddt 0.81 ptm 0.83 i_ptm 0.73 rg 0.82
# 70 models [2] recycles 1 hard 0 soft 0.80 temp 1 loss 4.82 helix 2.39 pae 0.22 i_pae 0.24 con 2.92 i_con 2.21 plddt 0.82 ptm 0.83 i_ptm 0.75 rg 0.86
# 71 models [2] recycles 1 hard 0 soft 0.84 temp 1 loss 4.84 helix 2.33 pae 0.22 i_pae 0.24 con 2.93 i_con 2.25 plddt 0.82 ptm 0.83 i_ptm 0.74 rg 0.69
# 72 models [1] recycles 1 hard 0 soft 0.88 temp 1 loss 4.76 helix 2.42 pae 0.21 i_pae 0.23 con 2.95 i_con 2.16 plddt 0.82 ptm 0.84 i_ptm 0.75 rg 0.79
# 73 models [3] recycles 1 hard 0 soft 0.92 temp 1 loss 6.52 helix 2.01 pae 0.45 i_pae 0.50 con 3.39 i_con 3.33 plddt 0.55 ptm 0.76 i_ptm 0.29 rg 0.31
# 74 models [1] recycles 1 hard 0 soft 0.96 temp 1 loss 5.35 helix 2.32 pae 0.23 i_pae 0.24 con 3.23 i_con 2.37 plddt 0.78 ptm 0.83 i_ptm 0.72 rg 0.99
# 75 models [1] recycles 1 hard 0 soft 1 temp 1 loss 4.88 helix 2.43 pae 0.21 i_pae 0.22 con 3.04 i_con 2.14 plddt 0.82 ptm 0.84 i_ptm 0.77 rg 0.96
# Optimised logit trajectory pLDDT: 0.84
# Stage 2: Softmax Optimisation
# 76 models [1] recycles 1 hard 0 soft 1 temp 0.96 loss 5.59 helix 2.27 pae 0.24 i_pae 0.26 con 3.27 i_con 2.51 plddt 0.75 ptm 0.83 i_ptm 0.69 rg 1.09
# 77 models [1] recycles 1 hard 0 soft 1 temp 0.91 loss 5.06 helix 2.26 pae 0.22 i_pae 0.23 con 3.11 i_con 2.17 plddt 0.82 ptm 0.84 i_ptm 0.76 rg 1.04
# 78 models [3] recycles 1 hard 0 soft 1 temp 0.87 loss 5.13 helix 2.27 pae 0.22 i_pae 0.24 con 3.09 i_con 2.23 plddt 0.81 ptm 0.84 i_ptm 0.75 rg 1.14
# 79 models [3] recycles 1 hard 0 soft 1 temp 0.83 loss 4.94 helix 2.22 pae 0.22 i_pae 0.23 con 2.97 i_con 2.19 plddt 0.83 ptm 0.84 i_ptm 0.76 rg 1.02
# 80 models [0] recycles 1 hard 0 soft 1 temp 0.79 loss 5.06 helix 2.28 pae 0.22 i_pae 0.24 con 3.05 i_con 2.27 plddt 0.81 ptm 0.84 i_ptm 0.74 rg 0.90
# 81 models [1] recycles 1 hard 0 soft 1 temp 0.75 loss 6.80 helix 1.92 pae 0.48 i_pae 0.54 con 3.50 i_con 3.54 plddt 0.51 ptm 0.75 i_ptm 0.25 rg 0.00
# 82 models [1] recycles 1 hard 0 soft 1 temp 0.72 loss 5.97 helix 2.13 pae 0.31 i_pae 0.33 con 3.35 i_con 2.86 plddt 0.67 ptm 0.80 i_ptm 0.54 rg 0.61
# 83 models [3] recycles 1 hard 0 soft 1 temp 0.68 loss 6.60 helix 1.92 pae 0.47 i_pae 0.52 con 3.41 i_con 3.37 plddt 0.54 ptm 0.75 i_ptm 0.28 rg 0.24
# 84 models [0] recycles 1 hard 0 soft 1 temp 0.64 loss 5.15 helix 2.23 pae 0.23 i_pae 0.24 con 3.07 i_con 2.34 plddt 0.80 ptm 0.84 i_ptm 0.73 rg 0.89
# 85 models [3] recycles 1 hard 0 soft 1 temp 0.61 loss 4.99 helix 2.23 pae 0.22 i_pae 0.24 con 3.00 i_con 2.25 plddt 0.82 ptm 0.84 i_ptm 0.74 rg 0.88
# 86 models [4] recycles 1 hard 0 soft 1 temp 0.58 loss 6.97 helix 1.88 pae 0.48 i_pae 0.53 con 3.74 i_con 3.41 plddt 0.52 ptm 0.76 i_ptm 0.28 rg 0.18
# 87 models [2] recycles 1 hard 0 soft 1 temp 0.54 loss 5.19 helix 2.19 pae 0.24 i_pae 0.25 con 3.09 i_con 2.27 plddt 0.80 ptm 0.83 i_ptm 0.74 rg 1.14
# 88 models [1] recycles 1 hard 0 soft 1 temp 0.51 loss 6.62 helix 2.02 pae 0.48 i_pae 0.53 con 3.42 i_con 3.45 plddt 0.51 ptm 0.76 i_ptm 0.27 rg 0.09
# 89 models [0] recycles 1 hard 0 soft 1 temp 0.48 loss 4.94 helix 2.25 pae 0.22 i_pae 0.23 con 2.99 i_con 2.21 plddt 0.81 ptm 0.84 i_ptm 0.75 rg 0.90
# 90 models [0] recycles 1 hard 0 soft 1 temp 0.45 loss 4.89 helix 2.43 pae 0.22 i_pae 0.23 con 2.96 i_con 2.24 plddt 0.81 ptm 0.84 i_ptm 0.75 rg 0.96
# 91 models [2] recycles 1 hard 0 soft 1 temp 0.42 loss 4.99 helix 2.23 pae 0.23 i_pae 0.25 con 2.93 i_con 2.29 plddt 0.81 ptm 0.83 i_ptm 0.73 rg 0.95
# 92 models [1] recycles 1 hard 0 soft 1 temp 0.39 loss 6.73 helix 2.18 pae 0.46 i_pae 0.51 con 3.50 i_con 3.50 plddt 0.54 ptm 0.76 i_ptm 0.29 rg 0.24
# 93 models [4] recycles 1 hard 0 soft 1 temp 0.37 loss 5.74 helix 2.18 pae 0.29 i_pae 0.31 con 3.19 i_con 2.76 plddt 0.72 ptm 0.81 i_ptm 0.61 rg 0.81
# 94 models [3] recycles 1 hard 0 soft 1 temp 0.34 loss 4.66 helix 2.46 pae 0.21 i_pae 0.23 con 2.78 i_con 2.27 plddt 0.82 ptm 0.84 i_ptm 0.75 rg 0.70
# 95 models [2] recycles 1 hard 0 soft 1 temp 0.32 loss 5.05 helix 2.25 pae 0.23 i_pae 0.24 con 3.03 i_con 2.29 plddt 0.81 ptm 0.83 i_ptm 0.74 rg 0.86
# 96 models [4] recycles 1 hard 0 soft 1 temp 0.29 loss 5.03 helix 2.38 pae 0.22 i_pae 0.23 con 3.04 i_con 2.28 plddt 0.82 ptm 0.84 i_ptm 0.76 rg 0.93
# 97 models [2] recycles 1 hard 0 soft 1 temp 0.27 loss 5.21 helix 2.24 pae 0.23 i_pae 0.24 con 3.10 i_con 2.32 plddt 0.82 ptm 0.83 i_ptm 0.74 rg 1.04
# 98 models [3] recycles 1 hard 0 soft 1 temp 0.25 loss 4.55 helix 2.44 pae 0.21 i_pae 0.22 con 2.78 i_con 2.17 plddt 0.84 ptm 0.84 i_ptm 0.77 rg 0.68
# 99 models [2] recycles 1 hard 0 soft 1 temp 0.23 loss 5.17 helix 2.18 pae 0.23 i_pae 0.25 con 3.10 i_con 2.29 plddt 0.81 ptm 0.84 i_ptm 0.74 rg 0.93
# 100 models [3] recycles 1 hard 0 soft 1 temp 0.21 loss 4.73 helix 2.54 pae 0.21 i_pae 0.23 con 2.89 i_con 2.18 plddt 0.83 ptm 0.84 i_ptm 0.76 rg 0.95
# 101 models [0] recycles 1 hard 0 soft 1 temp 0.19 loss 5.02 helix 2.22 pae 0.22 i_pae 0.23 con 2.95 i_con 2.32 plddt 0.80 ptm 0.85 i_ptm 0.74 rg 0.92
# 102 models [1] recycles 1 hard 0 soft 1 temp 0.17 loss 4.90 helix 2.25 pae 0.21 i_pae 0.23 con 2.99 i_con 2.20 plddt 0.82 ptm 0.85 i_ptm 0.75 rg 0.83
# 103 models [1] recycles 1 hard 0 soft 1 temp 0.15 loss 4.82 helix 2.38 pae 0.21 i_pae 0.22 con 2.94 i_con 2.19 plddt 0.82 ptm 0.84 i_ptm 0.76 rg 0.87
# 104 models [1] recycles 1 hard 0 soft 1 temp 0.14 loss 5.05 helix 2.31 pae 0.21 i_pae 0.23 con 3.04 i_con 2.25 plddt 0.82 ptm 0.84 i_ptm 0.75 rg 1.03
# 105 models [3] recycles 1 hard 0 soft 1 temp 0.12 loss 4.92 helix 2.34 pae 0.22 i_pae 0.24 con 2.94 i_con 2.26 plddt 0.82 ptm 0.84 i_ptm 0.74 rg 0.94
# 106 models [1] recycles 1 hard 0 soft 1 temp 0.11 loss 4.86 helix 2.18 pae 0.21 i_pae 0.22 con 2.95 i_con 2.16 plddt 0.83 ptm 0.84 i_ptm 0.76 rg 0.88
# 107 models [1] recycles 1 hard 0 soft 1 temp 0.09 loss 4.81 helix 2.30 pae 0.21 i_pae 0.22 con 2.92 i_con 2.20 plddt 0.82 ptm 0.84 i_ptm 0.76 rg 0.84
# 108 models [2] recycles 1 hard 0 soft 1 temp 0.08 loss 5.03 helix 2.20 pae 0.23 i_pae 0.24 con 3.02 i_con 2.25 plddt 0.82 ptm 0.83 i_ptm 0.73 rg 0.90
# 109 models [4] recycles 1 hard 0 soft 1 temp 0.07 loss 4.80 helix 2.37 pae 0.21 i_pae 0.23 con 2.92 i_con 2.19 plddt 0.83 ptm 0.84 i_ptm 0.76 rg 0.89
# 110 models [0] recycles 1 hard 0 soft 1 temp 0.06 loss 4.98 helix 2.22 pae 0.22 i_pae 0.23 con 3.01 i_con 2.21 plddt 0.82 ptm 0.84 i_ptm 0.75 rg 0.92
# 111 models [3] recycles 1 hard 0 soft 1 temp 0.05 loss 4.86 helix 2.40 pae 0.22 i_pae 0.23 con 2.89 i_con 2.27 plddt 0.83 ptm 0.84 i_ptm 0.75 rg 0.92
# 112 models [4] recycles 1 hard 0 soft 1 temp 0.04 loss 4.88 helix 2.29 pae 0.21 i_pae 0.22 con 2.97 i_con 2.16 plddt 0.84 ptm 0.84 i_ptm 0.77 rg 1.00
# 113 models [3] recycles 1 hard 0 soft 1 temp 0.03 loss 4.79 helix 2.33 pae 0.21 i_pae 0.23 con 2.86 i_con 2.23 plddt 0.82 ptm 0.84 i_ptm 0.75 rg 0.87
# 114 models [2] recycles 1 hard 0 soft 1 temp 0.03 loss 4.99 helix 2.37 pae 0.22 i_pae 0.23 con 3.03 i_con 2.23 plddt 0.83 ptm 0.84 i_ptm 0.75 rg 1.01
# 115 models [4] recycles 1 hard 0 soft 1 temp 0.02 loss 5.07 helix 2.25 pae 0.22 i_pae 0.23 con 3.07 i_con 2.24 plddt 0.82 ptm 0.84 i_ptm 0.76 rg 0.96
# 116 models [2] recycles 1 hard 0 soft 1 temp 0.02 loss 5.04 helix 2.21 pae 0.23 i_pae 0.25 con 2.98 i_con 2.32 plddt 0.81 ptm 0.83 i_ptm 0.73 rg 0.87
# 117 models [3] recycles 1 hard 0 soft 1 temp 0.01 loss 4.56 helix 2.42 pae 0.20 i_pae 0.22 con 2.80 i_con 2.08 plddt 0.84 ptm 0.85 i_ptm 0.78 rg 0.92
# 118 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 5.14 helix 2.17 pae 0.23 i_pae 0.25 con 2.98 i_con 2.42 plddt 0.79 ptm 0.83 i_ptm 0.71 rg 0.79
# 119 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 5.31 helix 2.23 pae 0.24 i_pae 0.26 con 3.08 i_con 2.47 plddt 0.79 ptm 0.83 i_ptm 0.70 rg 0.90
# 120 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 5.01 helix 2.29 pae 0.22 i_pae 0.23 con 3.07 i_con 2.21 plddt 0.83 ptm 0.85 i_ptm 0.76 rg 0.95
# Softmax trajectory pLDDT good, continuing: 0.84
# Stage 3: One-hot Optimisation
# 121 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.78 helix 2.32 pae 0.21 i_pae 0.22 con 2.94 i_con 2.12 plddt 0.82 ptm 0.85 i_ptm 0.78 rg 0.98
# 122 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 4.92 helix 2.26 pae 0.21 i_pae 0.23 con 2.89 i_con 2.32 plddt 0.79 ptm 0.84 i_ptm 0.73 rg 0.83
# 123 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 4.92 helix 2.16 pae 0.21 i_pae 0.23 con 2.96 i_con 2.21 plddt 0.80 ptm 0.85 i_ptm 0.75 rg 0.86
# 124 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 4.92 helix 2.26 pae 0.21 i_pae 0.23 con 2.89 i_con 2.32 plddt 0.79 ptm 0.84 i_ptm 0.73 rg 0.83
# 125 models [3] recycles 1 hard 1 soft 1 temp 0.01 loss 4.83 helix 2.27 pae 0.21 i_pae 0.23 con 2.92 i_con 2.15 plddt 0.82 ptm 0.84 i_ptm 0.76 rg 1.02
# One-hot trajectory pLDDT good, continuing: 0.82
# Stage 4: PSSM Semigreedy Optimisation
# Running semigreedy optimization...
# 126 models [3] recycles 1 hard 1 soft 0 temp 1 loss 5.86 helix 1.98 pae 0.28 i_pae 0.30 con 3.22 i_con 2.74 plddt 0.71 ptm 0.82 i_ptm 0.62 rg 1.03
# 127 models [1] recycles 1 hard 1 soft 0 temp 1 loss 5.89 helix 2.01 pae 0.28 i_pae 0.30 con 3.27 i_con 2.73 plddt 0.69 ptm 0.82 i_ptm 0.60 rg 1.01
# 128 models [2] recycles 1 hard 1 soft 0 temp 1 loss 5.78 helix 1.97 pae 0.27 i_pae 0.29 con 3.28 i_con 2.64 plddt 0.73 ptm 0.82 i_ptm 0.66 rg 0.92
# 129 models [4] recycles 1 hard 1 soft 0 temp 1 loss 5.75 helix 1.93 pae 0.26 i_pae 0.28 con 3.28 i_con 2.59 plddt 0.72 ptm 0.83 i_ptm 0.68 rg 0.92
# 130 models [3] recycles 1 hard 1 soft 0 temp 1 loss 5.31 helix 2.17 pae 0.25 i_pae 0.26 con 3.00 i_con 2.53 plddt 0.76 ptm 0.83 i_ptm 0.69 rg 0.89
# 131 models [3] recycles 1 hard 1 soft 0 temp 1 loss 7.12 helix 1.77 pae 0.41 i_pae 0.44 con 3.78 i_con 3.28 plddt 0.55 ptm 0.79 i_ptm 0.42 rg 1.04
# 132 models [0] recycles 1 hard 1 soft 0 temp 1 loss 6.94 helix 1.81 pae 0.52 i_pae 0.56 con 3.56 i_con 3.67 plddt 0.36 ptm 0.76 i_ptm 0.25 rg -0.41
# 133 models [3] recycles 1 hard 1 soft 0 temp 1 loss 6.92 helix 1.88 pae 0.54 i_pae 0.58 con 3.53 i_con 3.65 plddt 0.40 ptm 0.76 i_ptm 0.25 rg -0.21
# 134 models [1] recycles 1 hard 1 soft 0 temp 1 loss 7.03 helix 1.93 pae 0.55 i_pae 0.61 con 3.46 i_con 3.88 plddt 0.40 ptm 0.75 i_ptm 0.21 rg -0.36
# 135 models [0] recycles 1 hard 1 soft 0 temp 1 loss 7.12 helix 2.23 pae 0.57 i_pae 0.61 con 3.80 i_con 3.79 plddt 0.31 ptm 0.76 i_ptm 0.22 rg -0.63
# 136 models [2] recycles 1 hard 1 soft 0 temp 1 loss 7.29 helix 2.74 pae 0.58 i_pae 0.63 con 3.89 i_con 3.77 plddt 0.33 ptm 0.74 i_ptm 0.21 rg 0.18
# 137 models [4] recycles 1 hard 1 soft 0 temp 1 loss 6.76 helix 3.00 pae 0.54 i_pae 0.59 con 3.60 i_con 3.65 plddt 0.38 ptm 0.75 i_ptm 0.25 rg 0.12
# 138 models [1] recycles 1 hard 1 soft 0 temp 1 loss 6.60 helix 3.08 pae 0.50 i_pae 0.54 con 3.57 i_con 3.60 plddt 0.42 ptm 0.77 i_ptm 0.29 rg -0.02
# 139 models [1] recycles 1 hard 1 soft 0 temp 1 loss 6.51 helix 3.10 pae 0.49 i_pae 0.53 con 3.50 i_con 3.59 plddt 0.40 ptm 0.77 i_ptm 0.30 rg 0.01
# 140 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.02 helix 2.72 pae 0.56 i_pae 0.61 con 3.73 i_con 3.73 plddt 0.36 ptm 0.75 i_ptm 0.23 rg -0.01
# Trajectory successful, final pLDDT: 0.76
# Starting trajectory took: 0 hours, 3 minutes, 2 seconds
#
# Fixing interface residues: B4,B6,B9,B10,B13,B14,B16,B17,B18,B21,B24,B25
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn1, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn2, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn3, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn4, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn5, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn6, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn7, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn8, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn9, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn10, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn11, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn12, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn13, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn14, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn15, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn16, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn17, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn18, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn19, skipping interface scoring
# Base AF2 filters not passed for PDL1_l25_s160002_mpnn20, skipping interface scoring
# No accepted MPNN designs found for this trajectory.
# Design and validation of trajectory PDL1_l25_s160002 took: 0 hours, 0 minutes, 53 seconds
# Starting trajectory: PDL1_l25_s781634
# Starting SKINIT!
# Stage 1: Test Logits
# 1 models [2] recycles 1 hard 0 soft 0.02 temp 1 loss 9.53 helix 2.04 pae 0.68 i_pae 0.71 con 4.76 i_con 3.95 plddt 0.31 ptm 0.72 i_ptm 0.14 rg 3.25
# 2 models [1] recycles 1 hard 0 soft 0.04 temp 1 loss 9.37 helix 1.95 pae 0.64 i_pae 0.67 con 4.76 i_con 3.91 plddt 0.34 ptm 0.74 i_ptm 0.18 rg 2.83
# 3 models [4] recycles 1 hard 0 soft 0.05 temp 1 loss 8.29 helix 1.61 pae 0.59 i_pae 0.62 con 4.38 i_con 3.68 plddt 0.36 ptm 0.75 i_ptm 0.21 rg 1.04
# 4 models [2] recycles 1 hard 0 soft 0.07 temp 1 loss 8.48 helix 1.64 pae 0.63 i_pae 0.66 con 4.57 i_con 3.78 plddt 0.34 ptm 0.73 i_ptm 0.17 rg 0.68
# 5 models [2] recycles 1 hard 0 soft 0.09 temp 1 loss 8.63 helix 1.65 pae 0.61 i_pae 0.65 con 4.53 i_con 3.75 plddt 0.36 ptm 0.73 i_ptm 0.18 rg 1.43
# 6 models [0] recycles 1 hard 0 soft 0.11 temp 1 loss 8.07 helix 1.67 pae 0.58 i_pae 0.61 con 4.29 i_con 3.73 plddt 0.35 ptm 0.75 i_ptm 0.21 rg 0.50
# 7 models [0] recycles 1 hard 0 soft 0.13 temp 1 loss 8.35 helix 1.68 pae 0.59 i_pae 0.62 con 4.36 i_con 3.75 plddt 0.35 ptm 0.74 i_ptm 0.20 rg 1.12
# 8 models [1] recycles 1 hard 0 soft 0.14 temp 1 loss 8.64 helix 1.70 pae 0.60 i_pae 0.63 con 4.56 i_con 3.80 plddt 0.35 ptm 0.75 i_ptm 0.20 rg 1.26
# 9 models [3] recycles 1 hard 0 soft 0.16 temp 1 loss 8.11 helix 1.48 pae 0.57 i_pae 0.61 con 4.21 i_con 3.65 plddt 0.42 ptm 0.75 i_ptm 0.21 rg 1.06
# ...
# 100 models [0] recycles 1 hard 0 soft 1 temp 0.21 loss 8.03 helix 1.31 pae 0.54 i_pae 0.60 con 4.19 i_con 3.63 plddt 0.47 ptm 0.74 i_ptm 0.19 rg 0.79
# 101 models [2] recycles 1 hard 0 soft 1 temp 0.19 loss 7.65 helix 1.27 pae 0.48 i_pae 0.55 con 3.95 i_con 3.51 plddt 0.54 ptm 0.74 i_ptm 0.25 rg 0.79
# 102 models [1] recycles 1 hard 0 soft 1 temp 0.17 loss 7.42 helix 1.39 pae 0.45 i_pae 0.50 con 3.88 i_con 3.42 plddt 0.56 ptm 0.75 i_ptm 0.27 rg 0.74
# 103 models [2] recycles 1 hard 0 soft 1 temp 0.15 loss 7.89 helix 1.31 pae 0.56 i_pae 0.63 con 4.16 i_con 3.65 plddt 0.47 ptm 0.72 i_ptm 0.18 rg 0.30
# 104 models [1] recycles 1 hard 0 soft 1 temp 0.14 loss 7.06 helix 1.31 pae 0.33 i_pae 0.36 con 3.81 i_con 3.07 plddt 0.67 ptm 0.79 i_ptm 0.49 rg 1.13
# 105 models [4] recycles 1 hard 0 soft 1 temp 0.12 loss 7.74 helix 1.48 pae 0.55 i_pae 0.60 con 4.08 i_con 3.59 plddt 0.47 ptm 0.74 i_ptm 0.21 rg 0.49
# 106 models [1] recycles 1 hard 0 soft 1 temp 0.11 loss 7.38 helix 1.29 pae 0.37 i_pae 0.41 con 3.97 i_con 3.20 plddt 0.62 ptm 0.78 i_ptm 0.42 rg 1.14
# 107 models [1] recycles 1 hard 0 soft 1 temp 0.09 loss 7.15 helix 1.58 pae 0.36 i_pae 0.39 con 3.90 i_con 3.03 plddt 0.65 ptm 0.79 i_ptm 0.46 rg 1.52
# 108 models [1] recycles 1 hard 0 soft 1 temp 0.08 loss 7.97 helix 1.64 pae 0.55 i_pae 0.61 con 4.15 i_con 3.70 plddt 0.47 ptm 0.75 i_ptm 0.19 rg 0.80
# 109 models [3] recycles 1 hard 0 soft 1 temp 0.07 loss 8.20 helix 1.37 pae 0.57 i_pae 0.63 con 4.25 i_con 3.67 plddt 0.44 ptm 0.74 i_ptm 0.20 rg 1.01
# 110 models [1] recycles 1 hard 0 soft 1 temp 0.06 loss 7.87 helix 1.64 pae 0.54 i_pae 0.60 con 4.14 i_con 3.67 plddt 0.48 ptm 0.74 i_ptm 0.21 rg 0.61
# 111 models [4] recycles 1 hard 0 soft 1 temp 0.05 loss 7.62 helix 1.69 pae 0.55 i_pae 0.60 con 4.01 i_con 3.61 plddt 0.47 ptm 0.75 i_ptm 0.22 rg 0.49
# 112 models [1] recycles 1 hard 0 soft 1 temp 0.04 loss 7.93 helix 1.61 pae 0.51 i_pae 0.57 con 4.08 i_con 3.62 plddt 0.48 ptm 0.75 i_ptm 0.23 rg 1.19
# 113 models [0] recycles 1 hard 0 soft 1 temp 0.03 loss 7.96 helix 1.64 pae 0.55 i_pae 0.60 con 4.22 i_con 3.66 plddt 0.43 ptm 0.74 i_ptm 0.20 rg 0.67
# 114 models [4] recycles 1 hard 0 soft 1 temp 0.03 loss 7.75 helix 1.49 pae 0.56 i_pae 0.62 con 4.06 i_con 3.65 plddt 0.46 ptm 0.74 i_ptm 0.20 rg 0.35
# 115 models [1] recycles 1 hard 0 soft 1 temp 0.02 loss 6.80 helix 1.67 pae 0.31 i_pae 0.33 con 3.82 i_con 2.79 plddt 0.71 ptm 0.81 i_ptm 0.59 rg 1.59
# 116 models [3] recycles 1 hard 0 soft 1 temp 0.02 loss 8.34 helix 1.46 pae 0.59 i_pae 0.65 con 4.28 i_con 3.68 plddt 0.44 ptm 0.74 i_ptm 0.18 rg 1.41
# 117 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 7.83 helix 1.67 pae 0.53 i_pae 0.58 con 4.07 i_con 3.61 plddt 0.46 ptm 0.75 i_ptm 0.21 rg 0.97
# 118 models [3] recycles 1 hard 0 soft 1 temp 0.01 loss 7.79 helix 1.46 pae 0.51 i_pae 0.56 con 4.18 i_con 3.46 plddt 0.50 ptm 0.75 i_ptm 0.26 rg 0.81
# 119 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 8.11 helix 1.49 pae 0.54 i_pae 0.60 con 4.21 i_con 3.66 plddt 0.46 ptm 0.74 i_ptm 0.21 rg 1.06
# 120 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 7.92 helix 1.56 pae 0.54 i_pae 0.59 con 4.15 i_con 3.62 plddt 0.44 ptm 0.75 i_ptm 0.21 rg 0.84
# Softmax trajectory pLDDT good, continuing: 0.78
# Stage 3: One-hot Optimisation
# 121 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 8.01 helix 1.61 pae 0.53 i_pae 0.58 con 4.16 i_con 3.62 plddt 0.40 ptm 0.75 i_ptm 0.22 rg 1.16
# 122 models [1] recycles 1 hard 1 soft 1 temp 0.01 loss 7.91 helix 1.60 pae 0.52 i_pae 0.57 con 4.07 i_con 3.63 plddt 0.44 ptm 0.75 i_ptm 0.22 rg 1.10
# 123 models [2] recycles 1 hard 1 soft 1 temp 0.01 loss 7.90 helix 1.46 pae 0.54 i_pae 0.60 con 4.09 i_con 3.63 plddt 0.43 ptm 0.74 i_ptm 0.22 rg 0.82
# 124 models [3] recycles 1 hard 1 soft 1 temp 0.01 loss 7.07 helix 1.64 pae 0.37 i_pae 0.40 con 3.83 i_con 3.05 plddt 0.62 ptm 0.79 i_ptm 0.47 rg 1.42
# 125 models [3] recycles 1 hard 1 soft 1 temp 0.01 loss 6.71 helix 1.63 pae 0.32 i_pae 0.34 con 3.76 i_con 2.79 plddt 0.69 ptm 0.81 i_ptm 0.59 rg 1.48
# One-hot trajectory pLDDT good, continuing: 0.69
# Stage 4: PSSM Semigreedy Optimisation
# Running semigreedy optimization...
# 126 models [0] recycles 1 hard 1 soft 0 temp 1 loss 8.11 helix 1.59 pae 0.55 i_pae 0.60 con 4.23 i_con 3.66 plddt 0.38 ptm 0.75 i_ptm 0.19 rg 1.05
# 127 models [1] recycles 1 hard 1 soft 0 temp 1 loss 8.31 helix 1.48 pae 0.51 i_pae 0.56 con 4.37 i_con 3.57 plddt 0.44 ptm 0.75 i_ptm 0.24 rg 1.52
# 128 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.57 helix 1.59 pae 0.52 i_pae 0.57 con 3.99 i_con 3.51 plddt 0.44 ptm 0.75 i_ptm 0.23 rg 0.62
# 129 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.43 helix 1.62 pae 0.51 i_pae 0.57 con 3.87 i_con 3.50 plddt 0.43 ptm 0.75 i_ptm 0.24 rg 0.62
# 130 models [0] recycles 1 hard 1 soft 0 temp 1 loss 7.76 helix 1.54 pae 0.50 i_pae 0.54 con 4.10 i_con 3.48 plddt 0.41 ptm 0.76 i_ptm 0.26 rg 1.00
# 131 models [0] recycles 1 hard 1 soft 0 temp 1 loss 7.81 helix 1.52 pae 0.49 i_pae 0.53 con 4.09 i_con 3.46 plddt 0.42 ptm 0.76 i_ptm 0.27 rg 1.24
# 132 models [3] recycles 1 hard 1 soft 0 temp 1 loss 7.75 helix 1.36 pae 0.49 i_pae 0.54 con 4.04 i_con 3.48 plddt 0.46 ptm 0.76 i_ptm 0.27 rg 1.00
# 133 models [3] recycles 1 hard 1 soft 0 temp 1 loss 7.73 helix 1.45 pae 0.50 i_pae 0.55 con 4.01 i_con 3.45 plddt 0.45 ptm 0.76 i_ptm 0.26 rg 1.22
# 134 models [1] recycles 1 hard 1 soft 0 temp 1 loss 7.74 helix 1.44 pae 0.50 i_pae 0.55 con 4.04 i_con 3.51 plddt 0.43 ptm 0.76 i_ptm 0.25 rg 0.92
# 135 models [1] recycles 1 hard 1 soft 0 temp 1 loss 7.92 helix 1.45 pae 0.53 i_pae 0.58 con 4.18 i_con 3.62 plddt 0.40 ptm 0.76 i_ptm 0.23 rg 0.59
# 136 models [3] recycles 1 hard 1 soft 0 temp 1 loss 7.74 helix 1.43 pae 0.52 i_pae 0.57 con 4.04 i_con 3.52 plddt 0.44 ptm 0.75 i_ptm 0.25 rg 0.82
# 137 models [0] recycles 1 hard 1 soft 0 temp 1 loss 7.78 helix 1.40 pae 0.52 i_pae 0.56 con 4.10 i_con 3.57 plddt 0.39 ptm 0.75 i_ptm 0.23 rg 0.53
# 138 models [1] recycles 1 hard 1 soft 0 temp 1 loss 7.77 helix 1.40 pae 0.50 i_pae 0.55 con 4.04 i_con 3.59 plddt 0.44 ptm 0.76 i_ptm 0.26 rg 0.71
# 139 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.46 helix 1.43 pae 0.52 i_pae 0.57 con 3.89 i_con 3.56 plddt 0.42 ptm 0.76 i_ptm 0.24 rg 0.24
# 140 models [0] recycles 1 hard 1 soft 0 temp 1 loss 7.56 helix 1.35 pae 0.51 i_pae 0.55 con 3.96 i_con 3.58 plddt 0.39 ptm 0.76 i_ptm 0.24 rg 0.21
# Trajectory starting confidence low, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 3 minutes, 9 seconds
#
# Starting trajectory: PDL1_l25_s129911
# Starting SKINIT!
# Stage 1: Test Logits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8a2960c70177> in <cell line: 18>()
#      53
#      54         ### Begin binder hallucination
# ---> 55         trajectory = binder_hallucination(design_name, target_settings["starting_pdb"], target_settings["chains"],
#      56                                             target_settings["target_hotspot_residues"], length, seed, helicity_value,
#      57                                             design_models, advanced_settings, design_paths, failure_csv)
#
# /content/bindcraft/functions/colabdesign_utils.py in binder_hallucination(design_name, starting_pdb, chain, target_hotspot_residues, length, seed, helicity_value, design_models, advanced_settings, design_paths, failure_csv)
#     109         print("Stage 1: Test Logits")
#     110         af_model.design_logits(iters=50, e_soft=0.9, models=design_models, num_models=1, sample_models=advanced_settings["sample_models"], save_best=True)
# --> 111
#     112         # determine pLDDT of best iteration according to lowest 'loss' value
#     113         initial_plddt = get_best_plddt(af_model, length)
#
# /content/colabdesign/af/design.py in design_logits(self, iters, **kwargs)
#     352   def design_logits(self, iters=100, **kwargs):
#     353     ''' optimize logits '''
# --> 354     self.design(iters, **kwargs)
#     355
#     356   def design_soft(self, iters=100, temp=1, **kwargs):
#
# /content/colabdesign/af/design.py in design(self, iters, soft, e_soft, temp, e_temp, hard, e_hard, step, e_step, dropout, opt, weights, num_recycles, ramp_recycles, num_models, sample_models, models, backprop, callback, save_best, verbose)
#     346       lr_scale = step * ((1 - self.opt["soft"]) + (self.opt["soft"] * self.opt["temp"]))
#     347
# --> 348       self.step(lr_scale=lr_scale, num_recycles=num_recycles,
#     349                 num_models=num_models, sample_models=sample_models, models=models,
#     350                 backprop=backprop, callback=callback, save_best=save_best, verbose=verbose)
#
# /content/colabdesign/af/design.py in step(self, lr_scale, num_recycles, num_models, sample_models, models, backprop, callback, save_best, verbose)
#     212
#     213     # run
# --> 214     self.run(num_recycles=num_recycles, num_models=num_models, sample_models=sample_models,
#     215              models=models, backprop=backprop, callback=callback)
#     216
#
# /content/colabdesign/af/design.py in run(self, num_recycles, num_models, sample_models, models, backprop, callback, model_nums, return_aux)
#      94     for n in model_nums:
#      95       p = self._model_params[n]
# ---> 96       auxs.append(self._recycle(p, num_recycles=num_recycles, backprop=backprop))
#      97     auxs = jax.tree_map(lambda *x: np.stack(x), *auxs)
#      98
#
# /content/colabdesign/af/design.py in _recycle(self, model_params, num_recycles, backprop)
#     193       for m in mask:
#     194         if m == 0:
# --> 195           aux = self._single(model_params, backprop=False)
#     196         else:
#     197           aux = self._single(model_params, backprop)
#
# /content/colabdesign/af/design.py in _single(self, model_params, backprop)
#     140       (loss, aux), grad = self._model["grad_fn"](*flags)
#     141     else:
# --> 142       loss, aux = self._model["fn"](*flags)
#     143       grad = jax.tree_map(np.zeros_like, self._params)
#     144     aux.update({"loss":loss,"grad":grad})
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in cache_miss(*args, **kwargs)
#     330       raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     331                          "`jit`, but 'no_tracing' is set")
# --> 332     outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     333         fun, jit_info, *args, **kwargs)
#     334     executable = _read_most_recent_pjit_call_executable(jaxpr)
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     188
#     189   try:
# --> 190     out_flat = pjit_p.bind(*args_flat, **p.params)
#     191   except pxla.DeviceAssignmentMismatchError as e:
#     192     fails, = e.args
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind(self, *args, **params)
#    2780     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2781                  else axis_main.with_cur_sublevel())
# -> 2782     return self.bind_with_trace(top_trace, args, params)
#    2783
#    2784
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     441   def bind_with_trace(self, trace, args, params):
#     442     with pop_level(trace.level):
# --> 443       out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     444     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     445
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in process_primitive(self, primitive, tracers, params)
#     947       return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     948     else:
# --> 949       return primitive.impl(*tracers, **params)
#     950
#     951   def process_call(self, primitive, f, tracers, params):
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1737   has_explicit_sharding = _pjit_explicit_sharding_and_layout(
#    1738       in_shardings, out_shardings, in_layouts, out_layouts, None, None)
# -> 1739   return xc._xla.pjit(
#    1740       name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1741       tree_util.dispatch_registry, pxla.cc_shard_arg,
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in call_impl_cache_miss(*args_, **kwargs_)
#    1719                     donated_invars, name, keep_unused, inline):
#    1720   def call_impl_cache_miss(*args_, **kwargs_):
# -> 1721     out_flat, compiled = _pjit_call_impl_python(
#    1722         *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1723         out_shardings=out_shardings, in_layouts=in_layouts,
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/pjit.py in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1649       lowering_parameters=mlir.LoweringParameters(),
#    1650       pgle_profiler=pgle_profiler
# -> 1651   ).compile(compile_options)
#    1652
#    1653   _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/pxla.py in compile(self, compiler_options)
#    2311   def compile(self, compiler_options=None) -> MeshExecutable:
#    2312     if self._executable is None or compiler_options is not None:
# -> 2313       executable = UnloadedMeshExecutable.from_hlo(
#    2314           self._name, self._hlo, **self.compile_args,
#    2315           compiler_options=compiler_options)
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/pxla.py in from_hlo(***failed resolving arguments***)
#    2825           break
#    2826
# -> 2827     xla_executable = _cached_compilation(
#    2828         hlo, name, mesh, spmd_lowering,
#    2829         tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/pxla.py in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values, pgle_profiler)
#    2637       "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2638       fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2639     xla_executable = compiler.compile_or_get_cached(
#    2640         backend, computation, dev, compile_options, host_callbacks,
#    2641         pgle_profiler)
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/compiler.py in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, pgle_profiler)
#     424   else:
#     425     log_persistent_cache_miss(module_name, cache_key)
# --> 426     return _compile_and_write_cache(
#     427         backend,
#     428         computation,
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/compiler.py in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     652 ) -> xc.LoadedExecutable:
#     653   start_time = time.monotonic()
# --> 654   executable = backend_compile(
#     655       backend, computation, compile_options, host_callbacks
#     656   )
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     331   def wrapper(*args, **kwargs):
#     332     with TraceAnnotation(name, **decorator_kwargs):
# --> 333       return func(*args, **kwargs)
#     334     return wrapper
#     335   return wrapper
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/compiler.py in backend_compile(backend, module, options, host_callbacks)
#     264     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     265     # to take in `host_callbacks`
# --> 266     return backend.compile(built_c, compile_options=options)
#     267   except xc.XlaRuntimeError as e:
#     268     for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %%
#@title Consolidate & Rank Designs
#@markdown ---
accepted_binders = [f for f in os.listdir(design_paths["Accepted"]) if f.endswith('.pdb')]

for f in os.listdir(design_paths["Accepted/Ranked"]):
    os.remove(os.path.join(design_paths["Accepted/Ranked"], f))

# load dataframe of designed binders
design_df = pd.read_csv(mpnn_csv)
design_df = design_df.sort_values('Average_i_pTM', ascending=False)

# create final csv dataframe to copy matched rows, initialize with the column labels
final_df = pd.DataFrame(columns=final_labels)

# check the ranking of the designs and copy them with new ranked IDs to the folder
rank = 1
for _, row in design_df.iterrows():
    for binder in accepted_binders:
        target_settings["binder_name"], model = binder.rsplit('_model', 1)
        if target_settings["binder_name"] == row['Design']:
            # rank and copy into ranked folder
            row_data = {'Rank': rank, **{label: row[label] for label in design_labels}}
            final_df = pd.concat([final_df, pd.DataFrame([row_data])], ignore_index=True)
            old_path = os.path.join(design_paths["Accepted"], binder)
            new_path = os.path.join(design_paths["Accepted/Ranked"], f"{rank}_{target_settings['binder_name']}_model{model.rsplit('.', 1)[0]}.pdb")
            shutil.copyfile(old_path, new_path)

            rank += 1
            break

# save the final_df to final_csv
final_df.to_csv(final_csv, index=False)

print("Designs ranked and final_designs_stats.csv generated")

# %%
#@title Top 20 Designs
df = pd.read_csv(os.path.join(design_path, 'final_design_stats.csv'))
df.head(20)

# %%
#@title Top Design Display
import py3Dmol
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

# Visualise in PyMOL
view = py3Dmol.view()
view.addModel(open(top_design_pdb, 'r').read(),'pdb')
view.setBackgroundColor('white')
view.setStyle({'chain':'A'}, {'cartoon': {'color':'#3c5b6f'}})
view.setStyle({'chain':'B'}, {'cartoon': {'color':'#B76E79'}})
view.zoomTo()
view.show()

# %%
#@title Display animation
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

top_design_name = os.path.basename(top_design_pdb).split('1_', 1)[1].split('_mpnn')[0]
top_design_animation = os.path.join(design_path, 'Accepted', 'Animation', f"{top_design_name}.html")

# Show animation
HTML(top_design_animation)
